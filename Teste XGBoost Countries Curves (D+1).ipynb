# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from xgboost import XGBRegressor, plot_importance, plot_tree
from tqdm import tqdm_notebook
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
import math
import datetime as dt

# %matplotlib qt5

# %%
def get_mov_avg_std(df, col, N):
    """
    Given a dataframe, get mean and std dev at timestep t using values from t-1, t-2, ..., t-N.
    Inputs
        df         : dataframe. Can be of any length.
        col        : name of the column you want to calculate mean and std dev
        N          : get mean and std dev at timestep t using values from t-1, t-2, ..., t-N
    Outputs
        df_out     : same as df but with additional column containing mean and std dev
    """
    mean_list = df[col].rolling(window = N, min_periods=1).mean() # len(mean_list) = len(df)
    std_list = df[col].rolling(window = N, min_periods=1).std()   # first value will be NaN, because normalized by N-1
    
    # Add one timestep to the predictions
    mean_list = np.concatenate((np.array([np.nan]), np.array(mean_list[:-1])))
    std_list = np.concatenate((np.array([np.nan]), np.array(std_list[:-1])))
    
    # Append mean_list to df
    df_out = df.copy()
    df_out[col + '_mean'] = mean_list
    df_out[col + '_std'] = std_list
    
    return df_out

def scale_row(row, feat_mean, feat_std):
    """
    Given a pandas series in row, scale it to have 0 mean and var 1 using feat_mean and feat_std
    Inputs
        row      : pandas series. Need to scale this.
        feat_mean: mean  
        feat_std : standard deviation
    Outputs
        row_scaled : pandas series with same length as row, but scaled
    """
    # If feat_std = 0 (this happens if adj_close doesn't change over N days), 
    # set it to a small number to avoid division by zero
    feat_std = 0.001 if feat_std == 0 else feat_std
    
    row_scaled = (row-feat_mean) / feat_std
    
    return row_scaled

# %%
df_covid = pd.read_csv("./input/covid_19_clear.csv", parse_dates=['Date'], infer_datetime_format=True)

# %%
df_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6516 entries, 0 to 6515
# Data columns (total 8 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Country                                                             6516 non-null   object
#  1   Date                                                                6516 non-null   datetime64[ns]
#  2   Confirmed                                                           6516 non-null   int64
#  3   Deaths                                                              6516 non-null   int64
#  4   Recovered                                                           6364 non-null   float64
#  5   Case fatality rate of COVID-19 (%)                                  1794 non-null   float64
#  6   Daily new confirmed cases of COVID-19 (rolling 3-day average)       6516 non-null   float64
#  7   Daily new confirmed deaths due to COVID-19 (rolling 3-day average)  6516 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(2), object(1)
# memory usage: 407.4+ KB

# %%
ax = df_covid[df_covid['Country'] == 'Brazil'].plot(x='Date', y='Confirmed', style='b-', grid=True)
ax.set_xlabel("date")
ax.set_ylabel("Confirmed")
# Out:
# Text(0, 0.5, 'Confirmed')

# %%
df_info = pd.read_csv("./input/country_info.csv", parse_dates=['Lockdown Start Date'], infer_datetime_format=True)

# %%
df_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Country                              54 non-null     object
#  1   Age 0-9                              50 non-null     float64
#  2   Age 10-19                            50 non-null     float64
#  3   Age 20-29                            50 non-null     float64
#  4   Age 30-39                            50 non-null     float64
#  5   Age 40-49                            50 non-null     float64
#  6   Age 50-59                            50 non-null     float64
#  7   Age 60-69                            50 non-null     float64
#  8   Age 70-79                            50 non-null     float64
#  9   Age >80                              50 non-null     float64
#  10  # People                             50 non-null     float64
#  11  GDP                                  53 non-null     float64
#  12  GDP per capta                        54 non-null     float64
#  13  Life expectancy                      50 non-null     float64
#  14  # Flight Passengers                  46 non-null     float64
#  15  Hospital beds (per 1,000 people)     50 non-null     float64
#  16  Population density (people per km²)  54 non-null     float64
#  17  Lockdown Level                       54 non-null     int64
#  18  Lockdown Start Date                  44 non-null     datetime64[ns]
#  19  Temperature Jan (ºC)                 54 non-null     float64
#  20  Temperature Feb (ºC)                 54 non-null     float64
#  21  Temperature Mar (ºC)                 54 non-null     float64
#  22  Temperature Apr (ºC)                 54 non-null     float64
# dtypes: datetime64[ns](1), float64(20), int64(1), object(1)
# memory usage: 9.8+ KB

# %%
df = pd.merge(df_covid, df_info, left_on='Country', right_on='Country', how='inner', suffixes=('', ''))

# %%
del df_covid
del df_info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3202 entries, 0 to 3201
# Data columns (total 30 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Country                                                             3202 non-null   object
#  1   Date                                                                3202 non-null   datetime64[ns]
#  2   Confirmed                                                           3202 non-null   int64
#  3   Deaths                                                              3202 non-null   int64
#  4   Recovered                                                           3050 non-null   float64
#  5   Case fatality rate of COVID-19 (%)                                  1277 non-null   float64
#  6   Daily new confirmed cases of COVID-19 (rolling 3-day average)       3202 non-null   float64
#  7   Daily new confirmed deaths due to COVID-19 (rolling 3-day average)  3202 non-null   float64
#  8   Age 0-9                                                             3050 non-null   float64
#  9   Age 10-19                                                           3050 non-null   float64
#  10  Age 20-29                                                           3050 non-null   float64
#  11  Age 30-39                                                           3050 non-null   float64
#  12  Age 40-49                                                           3050 non-null   float64
#  13  Age 50-59                                                           3050 non-null   float64
#  14  Age 60-69                                                           3050 non-null   float64
#  15  Age 70-79                                                           3050 non-null   float64
#  16  Age >80                                                             3050 non-null   float64
#  17  # People                                                            3050 non-null   float64
#  18  GDP                                                                 3131 non-null   float64
#  19  GDP per capta                                                       3202 non-null   float64
#  20  Life expectancy                                                     3050 non-null   float64
#  21  # Flight Passengers                                                 2769 non-null   float64
#  22  Hospital beds (per 1,000 people)                                    3050 non-null   float64
#  23  Population density (people per km²)                                 3202 non-null   float64
#  24  Lockdown Level                                                      3202 non-null   int64
#  25  Lockdown Start Date                                                 2593 non-null   datetime64[ns]
#  26  Temperature Jan (ºC)                                                3202 non-null   float64
#  27  Temperature Feb (ºC)                                                3202 non-null   float64
#  28  Temperature Mar (ºC)                                                3202 non-null   float64
#  29  Temperature Apr (ºC)                                                3202 non-null   float64
# dtypes: datetime64[ns](2), float64(24), int64(3), object(1)
# memory usage: 775.5+ KB

# %%
n_cases = 50

df.loc[df['Date'].dt.month == 1, 'Country Temperature ºC'] = df['Temperature Jan (ºC)']
df.loc[df['Date'].dt.month == 2, 'Country Temperature ºC'] = df['Temperature Feb (ºC)']
df.loc[df['Date'].dt.month == 3, 'Country Temperature ºC'] = df['Temperature Mar (ºC)']
df.loc[df['Date'].dt.month == 4, 'Country Temperature ºC'] = df['Temperature Apr (ºC)']

df = df[df['Confirmed'] > n_cases]

# %%
from sklearn.preprocessing import LabelEncoder

lb_make = LabelEncoder()
df["country_code"] = lb_make.fit_transform(df["Country"])
df[["Country", "country_code"]]
# Out:
#         Country  country_code
# 12    Argentina             0
# 13    Argentina             0
# 14    Argentina             0
# 15    Argentina             0
# 16    Argentina             0
# ...         ...           ...
# 3197      Wuhan            53
# 3198      Wuhan            53
# 3199      Wuhan            53
# 3200      Wuhan            53
# 3201      Wuhan            53
#
# [1443 rows x 2 columns]

# %%
df.sort_values(by=['Country','Date'], inplace=True)

# %%
df_confirmed = df.drop(columns=['Temperature Jan (ºC)', 'Temperature Feb (ºC)', 'Temperature Mar (ºC)', 'Temperature Apr (ºC)', 'Deaths', 'Recovered', 'Daily new confirmed deaths due to COVID-19 (rolling 3-day average)', 'Hospital beds (per 1,000 people)', 'Lockdown Start Date'])
df_deaths = df.drop(columns=['Temperature Jan (ºC)', 'Temperature Feb (ºC)', 'Temperature Mar (ºC)', 'Temperature Apr (ºC)', 'Recovered', 'Lockdown Start Date'])

# %%
df_confirmed.head()
# Out:
#       Country       Date  Confirmed  Case fatality rate of COVID-19 (%)  \
# 12  Argentina 2020-03-16         56                                 NaN
# 13  Argentina 2020-03-17         68                                 NaN
# 14  Argentina 2020-03-18         79                                 NaN
# 15  Argentina 2020-03-19         97                                 NaN
# 16  Argentina 2020-03-20        128                             2.34375
#
#     Daily new confirmed cases of COVID-19 (rolling 3-day average)    Age 0-9  \
# 12                                          10.333333              7431085.0
# 13                                          11.333333              7431085.0
# 14                                          13.666667              7431085.0
# 15                                          21.000000              7431085.0
# 16                                          26.333333              7431085.0
#
#     Age 10-19  Age 20-29  Age 30-39  Age 40-49  ...   Age >80   # People  \
# 12  7110303.0  6989730.0  6393900.0  5596155.0  ...  818779.0  4441.8446
# 13  7110303.0  6989730.0  6393900.0  5596155.0  ...  818779.0  4441.8446
# 14  7110303.0  6989730.0  6393900.0  5596155.0  ...  818779.0  4441.8446
# 15  7110303.0  6989730.0  6393900.0  5596155.0  ...  818779.0  4441.8446
# 16  7110303.0  6989730.0  6393900.0  5596155.0  ...  818779.0  4441.8446
#
#               GDP  GDP per capta  Life expectancy  # Flight Passengers  \
# 12  813726.335884   10398.092465           76.372           18081937.0
# 13  813726.335884   10398.092465           76.372           18081937.0
# 14  813726.335884   10398.092465           76.372           18081937.0
# 15  813726.335884   10398.092465           76.372           18081937.0
# 16  813726.335884   10398.092465           76.372           18081937.0
#
#     Population density (people per km²)  Lockdown Level  \
# 12                            16.176856               3
# 13                            16.176856               3
# 14                            16.176856               3
# 15                            16.176856               3
# 16                            16.176856               3
#
#     Country Temperature ºC  country_code
# 12                    51.6             0
# 13                    51.6             0
# 14                    51.6             0
# 15                    51.6             0
# 16                    51.6             0
#
# [5 rows x 23 columns]

# %%
df_deaths.head()
# Out:
#       Country       Date  Confirmed  Deaths  \
# 12  Argentina 2020-03-16         56       2
# 13  Argentina 2020-03-17         68       2
# 14  Argentina 2020-03-18         79       2
# 15  Argentina 2020-03-19         97       3
# 16  Argentina 2020-03-20        128       3
#
#     Case fatality rate of COVID-19 (%)  \
# 12                                 NaN
# 13                                 NaN
# 14                                 NaN
# 15                                 NaN
# 16                             2.34375
#
#     Daily new confirmed cases of COVID-19 (rolling 3-day average)  \
# 12                                          10.333333
# 13                                          11.333333
# 14                                          13.666667
# 15                                          21.000000
# 16                                          26.333333
#
#     Daily new confirmed deaths due to COVID-19 (rolling 3-day average)  \
# 12                                           0.000000
# 13                                           0.000000
# 14                                           0.000000
# 15                                           0.333333
# 16                                           0.333333
#
#       Age 0-9  Age 10-19  Age 20-29  ...   # People            GDP  \
# 12  7431085.0  7110303.0  6989730.0  ...  4441.8446  813726.335884
# 13  7431085.0  7110303.0  6989730.0  ...  4441.8446  813726.335884
# 14  7431085.0  7110303.0  6989730.0  ...  4441.8446  813726.335884
# 15  7431085.0  7110303.0  6989730.0  ...  4441.8446  813726.335884
# 16  7431085.0  7110303.0  6989730.0  ...  4441.8446  813726.335884
#
#     GDP per capta  Life expectancy  # Flight Passengers  \
# 12   10398.092465           76.372           18081937.0
# 13   10398.092465           76.372           18081937.0
# 14   10398.092465           76.372           18081937.0
# 15   10398.092465           76.372           18081937.0
# 16   10398.092465           76.372           18081937.0
#
#     Hospital beds (per 1,000 people)  Population density (people per km²)  \
# 12                          6.352251                            16.176856
# 13                          6.352251                            16.176856
# 14                          6.352251                            16.176856
# 15                          6.352251                            16.176856
# 16                          6.352251                            16.176856
#
#     Lockdown Level  Country Temperature ºC  country_code
# 12               3                    51.6             0
# 13               3                    51.6             0
# 14               3                    51.6             0
# 15               3                    51.6             0
# 16               3                    51.6             0
#
# [5 rows x 26 columns]

# %% [markdown]
# # Predicting Confirmed

# %% [markdown]
# ## Feature Engeneering

# %%
# Add a column 'order_day' to indicate the order of the rows by date
for country in df_confirmed['Country'].unique():
    df_confirmed.loc[df_confirmed['Country'] == country, 'order_day'] = [x for x in list(range(len( df_confirmed.loc[df_confirmed['Country'] == country, :])))]

# merging_keys
merging_keys = ['Country', 'country_code','order_day']

# List of columns that we will use to create lags
lag_cols = df_confirmed.columns.values.tolist()[2:22]
lag_cols
# Out:
# ['Confirmed',
#  'Case fatality rate of COVID-19 (%)',
#  'Daily new confirmed cases of COVID-19 (rolling 3-day average)',
#  'Age 0-9',
#  'Age 10-19',
#  'Age 20-29',
#  'Age 30-39',
#  'Age 40-49',
#  'Age 50-59',
#  'Age 60-69',
#  'Age 70-79',
#  'Age >80',
#  '# People',
#  'GDP',
#  'GDP per capta',
#  'Life expectancy',
#  '# Flight Passengers',
#  'Population density (people per km²)',
#  'Lockdown Level',
#  'Country Temperature ºC']

# %%
N = 4
shift_range = [x+1 for x in range(N)]

for shift in tqdm_notebook(shift_range):
    train_shift = df_confirmed[merging_keys + lag_cols].copy()
    
    for country in df_confirmed['Country'].unique():    
        # E.g. order_day of 0 becomes 1, for shift = 1.
        # So when this is merged with order_day of 1 in df_confirmed, this will represent lag of 1.

        train_shift.loc[train_shift['Country'] == country, 'order_day'] =train_shift.loc[train_shift['Country'] == country, 'order_day'] + shift

    foo = lambda x: '{}_lag_{}'.format(x, shift) if x in lag_cols else x
    train_shift = train_shift.rename(columns=foo)

    df_confirmed = pd.merge(df_confirmed, train_shift, on=merging_keys, how='left')
    
del train_shift
# Out:
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   after removing the cwd from sys.path.
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))

# %%
df_confirmed[df_confirmed['Country'] == 'United States']
# Out:
#             Country       Date  Confirmed  Case fatality rate of COVID-19 (%)  \
# 1333  United States 2020-02-24         51                                 NaN
# 1334  United States 2020-02-25         51                                 NaN
# 1335  United States 2020-02-26         57                                 NaN
# 1336  United States 2020-02-27         58                                 NaN
# 1337  United States 2020-02-28         60                                 NaN
# 1338  United States 2020-02-29         68                                 NaN
# 1339  United States 2020-03-01         74                                 NaN
# 1340  United States 2020-03-02         98                                 NaN
# 1341  United States 2020-03-03        118                            5.825243
# 1342  United States 2020-03-04        149                            7.200000
# 1343  United States 2020-03-05        217                            6.918239
# 1344  United States 2020-03-06        262                            5.150215
# 1345  United States 2020-03-07        402                            4.142012
# 1346  United States 2020-03-08        518                            3.926097
# 1347  United States 2020-03-09        583                            3.790614
# 1348  United States 2020-03-10        959                            3.448276
# 1349  United States 2020-03-11       1281                            2.731707
# 1350  United States 2020-03-12       1663                            2.286585
# 1351  United States 2020-03-13       2179                            2.405292
# 1352  United States 2020-03-14       2727                            2.161914
# 1353  United States 2020-03-15       3499                            1.931549
# 1354  United States 2020-03-16       4632                            1.828299
# 1355  United States 2020-03-17       6421                            1.823643
# 1356  United States 2020-03-18       7783                            1.680411
# 1357  United States 2020-03-19      13677                            1.593202
# 1358  United States 2020-03-20      19100                            1.052632
# 1359  United States 2020-03-21      25489                            1.324908
# 1360  United States 2020-03-22      33276                            1.271171
# 1361  United States 2020-03-23      43847                            1.337840
# 1362  United States 2020-03-24      53740                            1.270402
# 1363  United States 2020-03-25      65778                            1.450272
# 1364  United States 2020-03-26      83836                            1.517473
# 1365  United States 2020-03-27     101657                            1.507134
# 1366  United States 2020-03-28     121478                            1.630591
# 1367  United States 2020-03-29     140886                            1.757510
# 1368  United States 2020-03-30     161807                            1.754239
# 1369  United States 2020-03-31     188172                            1.925647
# 1370  United States 2020-04-01     213372                            2.151167
#
#       Daily new confirmed cases of COVID-19 (rolling 3-day average)  \
# 1333                                           6.000000
# 1334                                           6.000000
# 1335                                           8.000000
# 1336                                           2.333333
# 1337                                           4.333333
# 1338                                           3.333333
# 1339                                           9.666667
# 1340                                          12.333333
# 1341                                          18.666667
# 1342                                          23.333333
# 1343                                          43.333333
# 1344                                          71.000000
# 1345                                          91.333333
# 1346                                         107.000000
# 1347                                         138.666667
# 1348                                         197.333333
# 1349                                         252.666667
# 1350                                         303.000000
# 1351                                         383.000000
# 1352                                         546.333333
# 1353                                         703.666667
# 1354                                         829.000000
# 1355                                        1158.666667
# 1356                                        1880.333333
# 1357                                        3196.333333
# 1358                                        4399.000000
# 1359                                        5777.333333
# 1360                                        6985.333333
# 1361                                        8939.333333
# 1362                                        9494.666667
# 1363                                       11329.333333
# 1364                                       13183.000000
# 1365                                       16485.000000
# 1366                                       18490.333333
# 1367                                       19011.333333
# 1368                                       19978.000000
# 1369                                       21651.000000
# 1370                                       23296.500000
#
#          Age 0-9   Age 10-19   Age 20-29   Age 30-39   Age 40-49  ...  \
# 1333  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1334  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1335  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1336  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1337  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1338  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1339  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1340  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1341  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1342  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1343  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1344  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1345  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1346  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1347  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1348  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1349  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1350  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1351  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1352  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1353  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1354  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1355  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1356  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1357  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1358  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1359  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1360  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1361  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1362  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1363  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1364  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1365  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1366  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1367  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1368  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1369  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
# 1370  39891845.0  42398071.0  46179065.0  43980069.0  40288440.0  ...
#
#       Age 70-79_lag_4  Age >80_lag_4  # People_lag_4     GDP_lag_4  \
# 1333              NaN            NaN             NaN           NaN
# 1334              NaN            NaN             NaN           NaN
# 1335              NaN            NaN             NaN           NaN
# 1336              NaN            NaN             NaN           NaN
# 1337       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1338       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1339       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1340       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1341       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1342       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1343       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1344       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1345       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1346       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1347       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1348       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1349       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1350       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1351       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1352       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1353       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1354       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1355       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1356       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1357       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1358       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1359       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1360       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1361       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1362       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1363       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1364       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1365       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1366       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1367       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1368       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1369       23009234.0      9052463.0      32520.1971  1.822948e+07
# 1370       23009234.0      9052463.0      32520.1971  1.822948e+07
#
#       GDP per capta_lag_4  Life expectancy_lag_4  # Flight Passengers_lag_4  \
# 1333                  NaN                    NaN                        NaN
# 1334                  NaN                    NaN                        NaN
# 1335                  NaN                    NaN                        NaN
# 1336                  NaN                    NaN                        NaN
# 1337           53128.5397                 78.861                889022000.0
# 1338           53128.5397                 78.861                889022000.0
# 1339           53128.5397                 78.861                889022000.0
# 1340           53128.5397                 78.861                889022000.0
# 1341           53128.5397                 78.861                889022000.0
# 1342           53128.5397                 78.861                889022000.0
# 1343           53128.5397                 78.861                889022000.0
# 1344           53128.5397                 78.861                889022000.0
# 1345           53128.5397                 78.861                889022000.0
# 1346           53128.5397                 78.861                889022000.0
# 1347           53128.5397                 78.861                889022000.0
# 1348           53128.5397                 78.861                889022000.0
# 1349           53128.5397                 78.861                889022000.0
# 1350           53128.5397                 78.861                889022000.0
# 1351           53128.5397                 78.861                889022000.0
# 1352           53128.5397                 78.861                889022000.0
# 1353           53128.5397                 78.861                889022000.0
# 1354           53128.5397                 78.861                889022000.0
# 1355           53128.5397                 78.861                889022000.0
# 1356           53128.5397                 78.861                889022000.0
# 1357           53128.5397                 78.861                889022000.0
# 1358           53128.5397                 78.861                889022000.0
# 1359           53128.5397                 78.861                889022000.0
# 1360           53128.5397                 78.861                889022000.0
# 1361           53128.5397                 78.861                889022000.0
# 1362           53128.5397                 78.861                889022000.0
# 1363           53128.5397                 78.861                889022000.0
# 1364           53128.5397                 78.861                889022000.0
# 1365           53128.5397                 78.861                889022000.0
# 1366           53128.5397                 78.861                889022000.0
# 1367           53128.5397                 78.861                889022000.0
# 1368           53128.5397                 78.861                889022000.0
# 1369           53128.5397                 78.861                889022000.0
# 1370           53128.5397                 78.861                889022000.0
#
#       Population density (people per km²)_lag_4  Lockdown Level_lag_4  \
# 1333                                        NaN                   NaN
# 1334                                        NaN                   NaN
# 1335                                        NaN                   NaN
# 1336                                        NaN                   NaN
# 1337                                  35.607765                   2.0
# 1338                                  35.607765                   2.0
# 1339                                  35.607765                   2.0
# 1340                                  35.607765                   2.0
# 1341                                  35.607765                   2.0
# 1342                                  35.607765                   2.0
# 1343                                  35.607765                   2.0
# 1344                                  35.607765                   2.0
# 1345                                  35.607765                   2.0
# 1346                                  35.607765                   2.0
# 1347                                  35.607765                   2.0
# 1348                                  35.607765                   2.0
# 1349                                  35.607765                   2.0
# 1350                                  35.607765                   2.0
# 1351                                  35.607765                   2.0
# 1352                                  35.607765                   2.0
# 1353                                  35.607765                   2.0
# 1354                                  35.607765                   2.0
# 1355                                  35.607765                   2.0
# 1356                                  35.607765                   2.0
# 1357                                  35.607765                   2.0
# 1358                                  35.607765                   2.0
# 1359                                  35.607765                   2.0
# 1360                                  35.607765                   2.0
# 1361                                  35.607765                   2.0
# 1362                                  35.607765                   2.0
# 1363                                  35.607765                   2.0
# 1364                                  35.607765                   2.0
# 1365                                  35.607765                   2.0
# 1366                                  35.607765                   2.0
# 1367                                  35.607765                   2.0
# 1368                                  35.607765                   2.0
# 1369                                  35.607765                   2.0
# 1370                                  35.607765                   2.0
#
#       Country Temperature ºC_lag_4
# 1333                           NaN
# 1334                           NaN
# 1335                           NaN
# 1336                           NaN
# 1337                           1.8
# 1338                           1.8
# 1339                           1.8
# 1340                           1.8
# 1341                           1.8
# 1342                           1.8
# 1343                           5.8
# 1344                           5.8
# 1345                           5.8
# 1346                           5.8
# 1347                           5.8
# 1348                           5.8
# 1349                           5.8
# 1350                           5.8
# 1351                           5.8
# 1352                           5.8
# 1353                           5.8
# 1354                           5.8
# 1355                           5.8
# 1356                           5.8
# 1357                           5.8
# 1358                           5.8
# 1359                           5.8
# 1360                           5.8
# 1361                           5.8
# 1362                           5.8
# 1363                           5.8
# 1364                           5.8
# 1365                           5.8
# 1366                           5.8
# 1367                           5.8
# 1368                           5.8
# 1369                           5.8
# 1370                           5.8
#
# [38 rows x 104 columns]

# %% [markdown]
# # Get mean and std dev at timestamp t using values from t-1, ..., t-N

# %%
cols_list = lag_cols

for col in cols_list:
    df_confirmed = get_mov_avg_std(df_confirmed, col, N)
df_confirmed.head()
# Out:
#      Country       Date  Confirmed  Case fatality rate of COVID-19 (%)  \
# 0  Argentina 2020-03-16         56                                 NaN
# 1  Argentina 2020-03-17         68                                 NaN
# 2  Argentina 2020-03-18         79                                 NaN
# 3  Argentina 2020-03-19         97                                 NaN
# 4  Argentina 2020-03-20        128                             2.34375
#
#    Daily new confirmed cases of COVID-19 (rolling 3-day average)    Age 0-9  \
# 0                                          10.333333              7431085.0
# 1                                          11.333333              7431085.0
# 2                                          13.666667              7431085.0
# 3                                          21.000000              7431085.0
# 4                                          26.333333              7431085.0
#
#    Age 10-19  Age 20-29  Age 30-39  Age 40-49  ...  Life expectancy_mean  \
# 0  7110303.0  6989730.0  6393900.0  5596155.0  ...                   NaN
# 1  7110303.0  6989730.0  6393900.0  5596155.0  ...                76.372
# 2  7110303.0  6989730.0  6393900.0  5596155.0  ...                76.372
# 3  7110303.0  6989730.0  6393900.0  5596155.0  ...                76.372
# 4  7110303.0  6989730.0  6393900.0  5596155.0  ...                76.372
#
#    Life expectancy_std  # Flight Passengers_mean  # Flight Passengers_std  \
# 0                  NaN                       NaN                      NaN
# 1                  NaN                18081937.0                      NaN
# 2                  0.0                18081937.0                      0.0
# 3                  0.0                18081937.0                      0.0
# 4                  0.0                18081937.0                      0.0
#
#    Population density (people per km²)_mean  \
# 0                                       NaN
# 1                                 16.176856
# 2                                 16.176856
# 3                                 16.176856
# 4                                 16.176856
#
#    Population density (people per km²)_std  Lockdown Level_mean  \
# 0                                      NaN                  NaN
# 1                                      NaN                  3.0
# 2                                      0.0                  3.0
# 3                                      0.0                  3.0
# 4                                      0.0                  3.0
#
#    Lockdown Level_std  Country Temperature ºC_mean  Country Temperature ºC_std
# 0                 NaN                          NaN                         NaN
# 1                 NaN                         51.6                         NaN
# 2                 0.0                         51.6                         0.0
# 3                 0.0                         51.6                         0.0
# 4                 0.0                         51.6                         0.0
#
# [5 rows x 144 columns]

# %% [markdown]
# # Split into train, validation and test set

# %%
valid_date = dt.datetime.today() - dt.timedelta(days=7)

mask_valid = (df_confirmed['Date'] >= valid_date )
mask_valid_br = ((df_confirmed['Date'] >= valid_date ) & (df_confirmed['Country'] == 'Brazil'))
mask_valid_sp = ((df_confirmed['Date'] >= valid_date ) & (df_confirmed['Country'] == 'São Paulo'))
mask_valid_nyc = ((df_confirmed['Date'] >= valid_date ) & (df_confirmed['Country'] == 'New York'))
mask_valid_sk = ((df_confirmed['Date'] >= valid_date ) & (df_confirmed['Country'] == 'South Korea'))
mask_valid_lombardia = ((df_confirmed['Date'] >= valid_date ) & (df_confirmed['Country'] == 'Lombardia'))
mask_valid_wuhua = ((df_confirmed['Date'] >= valid_date ) & (df_confirmed['Country'] == 'Wuhan'))


mask_train = (df_confirmed['Date'] < valid_date )

# Split into train, valid, and test
train = df_confirmed.loc[mask_train]
valid = df_confirmed.loc[mask_valid]
valid_br = df_confirmed.loc[mask_valid_br]
valid_sp = df_confirmed.loc[mask_valid_sp]
valid_nyc = df_confirmed.loc[mask_valid_nyc]
valid_sk = df_confirmed.loc[mask_valid_sk]
valid_lombardia = df_confirmed.loc[mask_valid_lombardia]
valid_wuhua = df_confirmed.loc[mask_valid_wuhua]

print("train.shape = " + str(train.shape))
print("valid.shape = " + str(valid.shape))
print("valid_br.shape = " + str(valid_br.shape))
print("valid_sp.shape = " + str(valid_sp.shape))
print("valid_nyc.shape = " + str(valid_nyc.shape))
print("valid_sk.shape = " + str(valid_sk.shape))
print("valid_lombardia.shape = " + str(valid_lombardia.shape))
print("valid_wuhua.shape = " + str(valid_wuhua.shape))
# Out:
# train.shape = (1175, 144)
# valid.shape = (268, 144)
# valid_br.shape = (5, 144)
# valid_sp.shape = (4, 144)
# valid_nyc.shape = (3, 144)
# valid_sk.shape = (5, 144)
# valid_lombardia.shape = (5, 144)
# valid_wuhua.shape = (6, 144)

# %% [markdown]
# # Scale the train, validation and test set¶

# %%
cols_to_scale = ['Confirmed']

for i in range(1,N+1):
    for col in lag_cols:
        print(col + "_lag_"+ str(i))
        cols_to_scale.append(col + "_lag_" + str(i))

# Do scaling for train set
# Here we only scale the train dataset, and not the entire dataset to prevent information leak
scaler = StandardScaler()
train_scaled = scaler.fit_transform(train[cols_to_scale])
print("scaler.mean_ = " + str(scaler.mean_))
print("scaler.var_ = " + str(scaler.var_))
print("train_scaled.shape = " + str(train_scaled.shape))

# Convert the numpy array back into pandas dataframe
train_scaled = pd.DataFrame(train_scaled, columns=cols_to_scale)
train_scaled[['Date', 'country_code']] = train.reset_index()[['Date', 'country_code']]
print("train_scaled.shape = " + str(train_scaled.shape))
train_scaled.head()
# Out:
# Confirmed_lag_1
# Case fatality rate of COVID-19 (%)_lag_1
# Daily new confirmed cases of COVID-19 (rolling 3-day average)_lag_1
# Age 0-9_lag_1
# Age 10-19_lag_1
# Age 20-29_lag_1
# Age 30-39_lag_1
# Age 40-49_lag_1
# Age 50-59_lag_1
# Age 60-69_lag_1
# Age 70-79_lag_1
# Age >80_lag_1
# # People_lag_1
# GDP_lag_1
# GDP per capta_lag_1
# Life expectancy_lag_1
# # Flight Passengers_lag_1
# Population density (people per km²)_lag_1
# Lockdown Level_lag_1
# Country Temperature ºC_lag_1
# Confirmed_lag_2
# Case fatality rate of COVID-19 (%)_lag_2
# Daily new confirmed cases of COVID-19 (rolling 3-day average)_lag_2
# Age 0-9_lag_2
# Age 10-19_lag_2
# Age 20-29_lag_2
# Age 30-39_lag_2
# Age 40-49_lag_2
# Age 50-59_lag_2
# Age 60-69_lag_2
# Age 70-79_lag_2
# Age >80_lag_2
# # People_lag_2
# GDP_lag_2
# GDP per capta_lag_2
# Life expectancy_lag_2
# # Flight Passengers_lag_2
# Population density (people per km²)_lag_2
# Lockdown Level_lag_2
# Country Temperature ºC_lag_2
# Confirmed_lag_3
# Case fatality rate of COVID-19 (%)_lag_3
# Daily new confirmed cases of COVID-19 (rolling 3-day average)_lag_3
# Age 0-9_lag_3
# Age 10-19_lag_3
# Age 20-29_lag_3
# Age 30-39_lag_3
# Age 40-49_lag_3
# Age 50-59_lag_3
# Age 60-69_lag_3
# Age 70-79_lag_3
# Age >80_lag_3
# # People_lag_3
# GDP_lag_3
# GDP per capta_lag_3
# Life expectancy_lag_3
# # Flight Passengers_lag_3
# Population density (people per km²)_lag_3
# Lockdown Level_lag_3
# Country Temperature ºC_lag_3
# Confirmed_lag_4
# Case fatality rate of COVID-19 (%)_lag_4
# Daily new confirmed cases of COVID-19 (rolling 3-day average)_lag_4
# Age 0-9_lag_4
# Age 10-19_lag_4
# Age 20-29_lag_4
# Age 30-39_lag_4
# Age 40-49_lag_4
# Age 50-59_lag_4
# Age 60-69_lag_4
# Age 70-79_lag_4
# Age >80_lag_4
# # People_lag_4
# GDP_lag_4
# GDP per capta_lag_4
# Life expectancy_lag_4
# # Flight Passengers_lag_4
# Population density (people per km²)_lag_4
# Lockdown Level_lag_4
# Country Temperature ºC_lag_4
# scaler.mean_ = [9.46127660e+03 9.28392864e+03 2.10323361e+00 4.14191793e+02
#  2.24686740e+07 2.23420778e+07 2.42006680e+07 2.59616415e+07
#  2.46639972e+07 2.28268516e+07 1.64453453e+07 8.45316348e+06
#  2.83920633e+06 1.70201625e+04 3.12753929e+06 3.37161341e+04
#  7.93690864e+01 1.24027889e+08 1.03343283e+03 2.17573595e+00
#  2.66684211e+01 9.15256232e+03 2.08250776e+00 3.89306779e+02
#  2.28078556e+07 2.26741322e+07 2.46076358e+07 2.64569924e+07
#  2.51813941e+07 2.33434521e+07 1.68156441e+07 8.63639086e+06
#  2.89741792e+06 1.73420915e+04 3.18507845e+06 3.38166620e+04
#  7.94184550e+01 1.26229759e+08 1.05425667e+03 2.17713215e+00
#  2.64198688e+01 9.07344620e+03 2.06216261e+00 3.68219151e+02
#  2.31849345e+07 2.30432878e+07 2.50600748e+07 2.70076898e+07
#  2.57566008e+07 2.39177734e+07 1.72273172e+07 8.84009057e+06
#  2.96213359e+06 1.76999902e+04 3.24882224e+06 3.39279076e+04
#  7.94733397e+01 1.28674813e+08 1.07730064e+03 2.17867720e+00
#  2.61448174e+01 9.04094891e+03 2.03785376e+00 3.50906500e+02
#  2.36066382e+07 2.34561303e+07 2.55660569e+07 2.76235585e+07
#  2.63998793e+07 2.45600616e+07 1.76877090e+07 9.06789675e+06
#  3.03450793e+06 1.81002438e+04 3.31983145e+06 3.40516814e+04
#  7.95347195e+01 1.31405692e+08 1.10293975e+03 2.18039625e+00
#  2.58387904e+01]
# scaler.var_ = [4.25696482e+08 4.17205091e+08 5.88395322e+00 1.28215598e+06
#  2.54936199e+15 2.57039621e+15 2.99174395e+15 3.52839540e+15
#  3.25564981e+15 2.87970477e+15 1.37490924e+15 2.81640611e+14
#  2.33640155e+13 1.43856327e+09 3.44046439e+13 5.71666371e+08
#  1.81488189e+01 4.30395069e+16 5.07130481e+06 1.32058878e+00
#  4.16609476e+02 4.13105464e+08 5.76085231e+00 1.08961844e+06
#  2.59448106e+15 2.61112642e+15 3.05191683e+15 3.61521202e+15
#  3.34550190e+15 2.96481442e+15 1.41530638e+15 2.89624071e+14
#  2.39814909e+13 1.47360457e+09 3.52852173e+13 5.67465089e+08
#  1.79328246e+01 4.39741065e+16 5.17446373e+06 1.31913967e+00
#  4.15543616e+02 4.13194995e+08 5.62020820e+00 9.46603221e+05
#  2.64437127e+15 2.65614864e+15 3.11842412e+15 3.71115276e+15
#  3.44476486e+15 3.05880700e+15 1.45989525e+15 2.98420721e+14
#  2.46600026e+13 1.51231778e+09 3.62530146e+13 5.62792334e+08
#  1.76869749e+01 4.50005653e+16 5.28760995e+06 1.31753152e+00
#  4.14220104e+02 4.16362885e+08 5.36349632e+00 8.47127870e+05
#  2.69982881e+15 2.70617609e+15 3.19231714e+15 3.81772898e+15
#  3.55499109e+15 3.16314155e+15 1.50935941e+15 3.08160095e+14
#  2.54088898e+13 1.55530899e+09 3.73215513e+13 5.57564255e+08
#  1.74048944e+01 4.61328819e+16 5.41225020e+06 1.31573665e+00
#  4.12569715e+02]
# train_scaled.shape = (1175, 81)
# train_scaled.shape = (1175, 83)
#    Confirmed  Confirmed_lag_1  Case fatality rate of COVID-19 (%)_lag_1  \
# 0  -0.455850              NaN                                       NaN
# 1  -0.455268        -0.451783                                       NaN
# 2  -0.454735        -0.451195                                       NaN
# 3  -0.453862        -0.450656                                       NaN
# 4  -0.452360        -0.449775                                       NaN
#
#    Daily new confirmed cases of COVID-19 (rolling 3-day average)_lag_1  \
# 0                                                NaN
# 1                                          -0.356664
# 2                                          -0.355780
# 3                                          -0.353720
# 4                                          -0.347243
#
#    Age 0-9_lag_1  Age 10-19_lag_1  Age 20-29_lag_1  Age 30-39_lag_1  \
# 0            NaN              NaN              NaN              NaN
# 1      -0.297826        -0.300435        -0.314661        -0.329422
# 2      -0.297826        -0.300435        -0.314661        -0.329422
# 3      -0.297826        -0.300435        -0.314661        -0.329422
# 4      -0.297826        -0.300435        -0.314661        -0.329422
#
#    Age 40-49_lag_1  Age 50-59_lag_1  ...  # People_lag_4  GDP_lag_4  \
# 0              NaN              NaN  ...             NaN        NaN
# 1        -0.334182        -0.344018  ...             NaN        NaN
# 2        -0.334182        -0.344018  ...             NaN        NaN
# 3        -0.334182        -0.344018  ...             NaN        NaN
# 4        -0.334182        -0.344018  ...       -0.346331  -0.410222
#
#    GDP per capta_lag_4  Life expectancy_lag_4  # Flight Passengers_lag_4  \
# 0                  NaN                    NaN                        NaN
# 1                  NaN                    NaN                        NaN
# 2                  NaN                    NaN                        NaN
# 3                  NaN                    NaN                        NaN
# 4            -1.001727              -0.758097                  -0.527613
#
#    Population density (people per km²)_lag_4  Lockdown Level_lag_4  \
# 0                                        NaN                   NaN
# 1                                        NaN                   NaN
# 2                                        NaN                   NaN
# 3                                        NaN                   NaN
# 4                                  -0.467139              0.714528
#
#    Country Temperature ºC_lag_4       Date  country_code
# 0                           NaN 2020-03-16             0
# 1                           NaN 2020-03-17             0
# 2                           NaN 2020-03-18             0
# 3                           NaN 2020-03-19             0
# 4                      1.268287 2020-03-20             0
#
# [5 rows x 83 columns]

# %%
valid_scaled = valid[['Date', 'country_code']]
for col in tqdm_notebook(cols_list):
    feat_list = [col + '_lag_' + str(shift) for shift in range(1, N+1)]
    temp = valid.apply(lambda row: scale_row(row[feat_list], row[col+'_mean'], row[col+'_std']), axis=1)
    valid_scaled = pd.concat([valid_scaled, temp], axis=1)
    
# Now the entire valid set is scaled
valid_scaled.head()
# Out:
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
#          Date  country_code  Confirmed_lag_1  Confirmed_lag_2  \
# 12 2020-03-28             0         1.250497         0.364198
# 13 2020-03-29             0         1.149419         0.365018
# 14 2020-03-30             0         1.052597         0.542528
# 15 2020-03-31             0         1.121034         0.349680
# 16 2020-04-01             0         1.414696        -0.045233
#
#     Confirmed_lag_3  Confirmed_lag_4  \
# 12        -0.807347        -0.807347
# 13        -0.310654        -1.203783
# 14        -0.394144        -1.200980
# 15        -0.215979        -1.254735
# 16        -0.513159        -0.856304
#
#     Case fatality rate of COVID-19 (%)_lag_1  \
# 12                                  1.380777
# 13                                  1.287655
# 14                                  0.884504
# 15                                  0.290547
# 16                                  0.001509
#
#     Case fatality rate of COVID-19 (%)_lag_2  \
# 12                                 -0.114367
# 13                                  0.293822
# 14                                  0.687701
# 15                                  0.777579
# 16                                 -0.950836
#
#     Case fatality rate of COVID-19 (%)_lag_3  \
# 12                                 -0.260058
# 13                                 -0.740352
# 14                                 -0.281718
# 15                                  0.398811
# 16                                  1.381663
#
#     Case fatality rate of COVID-19 (%)_lag_4  ...  \
# 12                                 -1.006352  ...
# 13                                 -0.841125  ...
# 14                                 -1.290487  ...
# 15                                 -1.466937  ...
# 16                                 -0.432337  ...
#
#     Population density (people per km²)_lag_3  \
# 12                                        0.0
# 13                                        0.0
# 14                                        0.0
# 15                                        0.0
# 16                                        0.0
#
#     Population density (people per km²)_lag_4  Lockdown Level_lag_1  \
# 12                                        0.0                   0.0
# 13                                        0.0                   0.0
# 14                                        0.0                   0.0
# 15                                        0.0                   0.0
# 16                                        0.0                   0.0
#
#     Lockdown Level_lag_2  Lockdown Level_lag_3  Lockdown Level_lag_4  \
# 12                   0.0                   0.0                   0.0
# 13                   0.0                   0.0                   0.0
# 14                   0.0                   0.0                   0.0
# 15                   0.0                   0.0                   0.0
# 16                   0.0                   0.0                   0.0
#
#     Country Temperature ºC_lag_1  Country Temperature ºC_lag_2  \
# 12                           0.0                           0.0
# 13                           0.0                           0.0
# 14                           0.0                           0.0
# 15                           0.0                           0.0
# 16                           0.0                           0.0
#
#     Country Temperature ºC_lag_3  Country Temperature ºC_lag_4
# 12                           0.0                           0.0
# 13                           0.0                           0.0
# 14                           0.0                           0.0
# 15                           0.0                           0.0
# 16                           0.0                           0.0
#
# [5 rows x 82 columns]

# %%
valid_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 268 entries, 12 to 1442
# Data columns (total 82 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Date                                                                 268 non-null    datetime64[ns]
#  1   country_code                                                         268 non-null    int64
#  2   Confirmed_lag_1                                                      268 non-null    float64
#  3   Confirmed_lag_2                                                      268 non-null    float64
#  4   Confirmed_lag_3                                                      268 non-null    float64
#  5   Confirmed_lag_4                                                      268 non-null    float64
#  6   Case fatality rate of COVID-19 (%)_lag_1                             268 non-null    float64
#  7   Case fatality rate of COVID-19 (%)_lag_2                             268 non-null    float64
#  8   Case fatality rate of COVID-19 (%)_lag_3                             268 non-null    float64
#  9   Case fatality rate of COVID-19 (%)_lag_4                             268 non-null    float64
#  10  Daily new confirmed cases of COVID-19 (rolling 3-day average)_lag_1  268 non-null    float64
#  11  Daily new confirmed cases of COVID-19 (rolling 3-day average)_lag_2  268 non-null    float64
#  12  Daily new confirmed cases of COVID-19 (rolling 3-day average)_lag_3  268 non-null    float64
#  13  Daily new confirmed cases of COVID-19 (rolling 3-day average)_lag_4  268 non-null    float64
#  14  Age 0-9_lag_1                                                        250 non-null    float64
#  15  Age 0-9_lag_2                                                        250 non-null    float64
#  16  Age 0-9_lag_3                                                        250 non-null    float64
#  17  Age 0-9_lag_4                                                        250 non-null    float64
#  18  Age 10-19_lag_1                                                      250 non-null    float64
#  19  Age 10-19_lag_2                                                      250 non-null    float64
#  20  Age 10-19_lag_3                                                      250 non-null    float64
#  21  Age 10-19_lag_4                                                      250 non-null    float64
#  22  Age 20-29_lag_1                                                      250 non-null    float64
#  23  Age 20-29_lag_2                                                      250 non-null    float64
#  24  Age 20-29_lag_3                                                      250 non-null    float64
#  25  Age 20-29_lag_4                                                      250 non-null    float64
#  26  Age 30-39_lag_1                                                      250 non-null    float64
#  27  Age 30-39_lag_2                                                      250 non-null    float64
#  28  Age 30-39_lag_3                                                      250 non-null    float64
#  29  Age 30-39_lag_4                                                      250 non-null    float64
#  30  Age 40-49_lag_1                                                      250 non-null    float64
#  31  Age 40-49_lag_2                                                      250 non-null    float64
#  32  Age 40-49_lag_3                                                      250 non-null    float64
#  33  Age 40-49_lag_4                                                      250 non-null    float64
#  34  Age 50-59_lag_1                                                      250 non-null    float64
#  35  Age 50-59_lag_2                                                      250 non-null    float64
#  36  Age 50-59_lag_3                                                      250 non-null    float64
#  37  Age 50-59_lag_4                                                      250 non-null    float64
#  38  Age 60-69_lag_1                                                      250 non-null    float64
#  39  Age 60-69_lag_2                                                      250 non-null    float64
#  40  Age 60-69_lag_3                                                      250 non-null    float64
#  41  Age 60-69_lag_4                                                      250 non-null    float64
#  42  Age 70-79_lag_1                                                      250 non-null    float64
#  43  Age 70-79_lag_2                                                      250 non-null    float64
#  44  Age 70-79_lag_3                                                      250 non-null    float64
#  45  Age 70-79_lag_4                                                      250 non-null    float64
#  46  Age >80_lag_1                                                        250 non-null    float64
#  47  Age >80_lag_2                                                        250 non-null    float64
#  48  Age >80_lag_3                                                        250 non-null    float64
#  49  Age >80_lag_4                                                        250 non-null    float64
#  50  # People_lag_1                                                       250 non-null    float64
#  51  # People_lag_2                                                       250 non-null    float64
#  52  # People_lag_3                                                       250 non-null    float64
#  53  # People_lag_4                                                       250 non-null    float64
#  54  GDP_lag_1                                                            263 non-null    float64
#  55  GDP_lag_2                                                            263 non-null    float64
#  56  GDP_lag_3                                                            263 non-null    float64
#  57  GDP_lag_4                                                            263 non-null    float64
#  58  GDP per capta_lag_1                                                  268 non-null    float64
#  59  GDP per capta_lag_2                                                  268 non-null    float64
#  60  GDP per capta_lag_3                                                  268 non-null    float64
#  61  GDP per capta_lag_4                                                  268 non-null    float64
#  62  Life expectancy_lag_1                                                250 non-null    float64
#  63  Life expectancy_lag_2                                                250 non-null    float64
#  64  Life expectancy_lag_3                                                250 non-null    float64
#  65  Life expectancy_lag_4                                                250 non-null    float64
#  66  # Flight Passengers_lag_1                                            230 non-null    float64
#  67  # Flight Passengers_lag_2                                            230 non-null    float64
#  68  # Flight Passengers_lag_3                                            230 non-null    float64
#  69  # Flight Passengers_lag_4                                            230 non-null    float64
#  70  Population density (people per km²)_lag_1                            268 non-null    float64
#  71  Population density (people per km²)_lag_2                            268 non-null    float64
#  72  Population density (people per km²)_lag_3                            268 non-null    float64
#  73  Population density (people per km²)_lag_4                            268 non-null    float64
#  74  Lockdown Level_lag_1                                                 268 non-null    float64
#  75  Lockdown Level_lag_2                                                 268 non-null    float64
#  76  Lockdown Level_lag_3                                                 268 non-null    float64
#  77  Lockdown Level_lag_4                                                 268 non-null    float64
#  78  Country Temperature ºC_lag_1                                         268 non-null    float64
#  79  Country Temperature ºC_lag_2                                         268 non-null    float64
#  80  Country Temperature ºC_lag_3                                         268 non-null    float64
#  81  Country Temperature ºC_lag_4                                         268 non-null    float64
# dtypes: datetime64[ns](1), float64(80), int64(1)
# memory usage: 173.8 KB

# %%
valid_br_scaled = valid_br[['Date', 'country_code']]
for col in tqdm_notebook(cols_list):
    feat_list = [col + '_lag_' + str(shift) for shift in range(1, N+1)]
    temp = valid_br.apply(lambda row: scale_row(row[feat_list], row[col+'_mean'], row[col+'_std']), axis=1)
    valid_br_scaled = pd.concat([valid_br_scaled, temp], axis=1)
    
# Now the entire valid_br set is scaled
valid_br_scaled.head()
# Out:
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
#           Date  country_code  Confirmed_lag_1  Confirmed_lag_2  \
# 116 2020-03-28             4         1.207609         0.361058
# 117 2020-03-29             4         1.190206         0.348943
# 118 2020-03-30             4         1.106718         0.473794
# 119 2020-03-31             4         1.084493         0.435806
# 120 2020-04-01             4         1.404555        -0.044569
#
#      Confirmed_lag_3  Confirmed_lag_4  \
# 116        -0.483533        -1.085133
# 117        -0.397311        -1.141838
# 118        -0.401871        -1.178641
# 119        -0.271123        -1.249176
# 120        -0.455876        -0.904111
#
#      Case fatality rate of COVID-19 (%)_lag_1  \
# 116                                  1.177860
# 117                                  0.893473
# 118                                  1.140643
# 119                                  1.316881
# 120                                  1.190251
#
#      Case fatality rate of COVID-19 (%)_lag_2  \
# 116                                  0.346935
# 117                                  0.712068
# 118                                  0.181995
# 119                                  0.228130
# 120                                  0.371019
#
#      Case fatality rate of COVID-19 (%)_lag_3  \
# 116                                 -0.356328
# 117                                 -0.352335
# 118                                 -0.032382
# 119                                 -0.671874
# 120                                 -0.443839
#
#      Case fatality rate of COVID-19 (%)_lag_4  ...  \
# 116                                 -1.168466  ...
# 117                                 -1.253206  ...
# 118                                 -1.290257  ...
# 119                                 -0.873137  ...
# 120                                 -1.117432  ...
#
#      Population density (people per km²)_lag_3  \
# 116                               9.237056e-11
# 117                               9.237056e-11
# 118                               9.237056e-11
# 119                               9.237056e-11
# 120                               9.237056e-11
#
#      Population density (people per km²)_lag_4  Lockdown Level_lag_1  \
# 116                               9.237056e-11                   0.0
# 117                               9.237056e-11                   0.0
# 118                               9.237056e-11                   0.0
# 119                               9.237056e-11                   0.0
# 120                               9.237056e-11                   0.0
#
#      Lockdown Level_lag_2  Lockdown Level_lag_3  Lockdown Level_lag_4  \
# 116                   0.0                   0.0                   0.0
# 117                   0.0                   0.0                   0.0
# 118                   0.0                   0.0                   0.0
# 119                   0.0                   0.0                   0.0
# 120                   0.0                   0.0                   0.0
#
#      Country Temperature ºC_lag_1  Country Temperature ºC_lag_2  \
# 116                 -1.421085e-11                 -1.421085e-11
# 117                 -1.421085e-11                 -1.421085e-11
# 118                 -1.421085e-11                 -1.421085e-11
# 119                 -1.421085e-11                 -1.421085e-11
# 120                 -1.421085e-11                 -1.421085e-11
#
#      Country Temperature ºC_lag_3  Country Temperature ºC_lag_4
# 116                 -1.421085e-11                 -1.421085e-11
# 117                 -1.421085e-11                 -1.421085e-11
# 118                 -1.421085e-11                 -1.421085e-11
# 119                 -1.421085e-11                 -1.421085e-11
# 120                 -1.421085e-11                 -1.421085e-11
#
# [5 rows x 82 columns]

# %%
valid_sp_scaled = valid_sp[['Date', 'country_code']]
for col in tqdm_notebook(cols_list):
    feat_list = [col + '_lag_' + str(shift) for shift in range(1, N+1)]
    temp = valid_sp.apply(lambda row: scale_row(row[feat_list], row[col+'_mean'], row[col+'_std']), axis=1)
    valid_sp_scaled = pd.concat([valid_sp_scaled, temp], axis=1)
    
# Now the entire valid_sp set is scaled
valid_sp_scaled.head()
# Out:
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
#            Date  country_code  Confirmed_lag_1  Confirmed_lag_2  \
# 1261 2020-03-28            48         0.942716         0.488961
# 1262 2020-03-29            48         0.763291         0.763291
# 1263 2020-03-30            48         0.500000         0.500000
# 1264 2020-03-31            48         1.500000        -0.500000
#
#       Confirmed_lag_3  Confirmed_lag_4  \
# 1261        -0.064934        -1.366743
# 1262        -0.184693        -1.341888
# 1263         0.500000        -1.500000
# 1264        -0.500000        -0.500000
#
#       Case fatality rate of COVID-19 (%)_lag_1  \
# 1261                                 -0.512702
# 1262                                 -0.321144
# 1263                                  0.500000
# 1264                                  1.500000
#
#       Case fatality rate of COVID-19 (%)_lag_2  \
# 1261                                 -0.527642
# 1262                                 -0.321144
# 1263                                  0.500000
# 1264                                 -0.500000
#
#       Case fatality rate of COVID-19 (%)_lag_3  \
# 1261                                 -0.459004
# 1262                                 -0.816281
# 1263                                  0.500000
# 1264                                 -0.500000
#
#       Case fatality rate of COVID-19 (%)_lag_4  ...  \
# 1261                                  1.499348  ...
# 1262                                  1.458568  ...
# 1263                                 -1.500000  ...
# 1264                                 -0.500000  ...
#
#       Population density (people per km²)_lag_3  \
# 1261                                        0.0
# 1262                                        0.0
# 1263                                        0.0
# 1264                                        0.0
#
#       Population density (people per km²)_lag_4  Lockdown Level_lag_1  \
# 1261                                        0.0                   0.0
# 1262                                        0.0                   0.0
# 1263                                        0.0                   0.0
# 1264                                        0.0                   0.0
#
#       Lockdown Level_lag_2  Lockdown Level_lag_3  Lockdown Level_lag_4  \
# 1261                   0.0                   0.0                   0.0
# 1262                   0.0                   0.0                   0.0
# 1263                   0.0                   0.0                   0.0
# 1264                   0.0                   0.0                   0.0
#
#       Country Temperature ºC_lag_1  Country Temperature ºC_lag_2  \
# 1261                 -8.429370e-08                 -8.429370e-08
# 1262                 -8.429370e-08                 -8.429370e-08
# 1263                 -8.429370e-08                 -8.429370e-08
# 1264                 -8.429370e-08                 -8.429370e-08
#
#       Country Temperature ºC_lag_3  Country Temperature ºC_lag_4
# 1261                 -8.429370e-08                 -8.429370e-08
# 1262                 -8.429370e-08                 -8.429370e-08
# 1263                 -8.429370e-08                 -8.429370e-08
# 1264                 -8.429370e-08                 -8.429370e-08
#
# [4 rows x 82 columns]

# %%
valid_nyc_scaled = valid_nyc[['Date', 'country_code']]
for col in tqdm_notebook(cols_list):
    feat_list = [col + '_lag_' + str(shift) for shift in range(1, N+1)]
    temp = valid_nyc.apply(lambda row: scale_row(row[feat_list], row[col+'_mean'], row[col+'_std']), axis=1)
    valid_nyc_scaled = pd.concat([valid_nyc_scaled, temp], axis=1)
    
# Now the entire valid_nyc set is scaled
valid_nyc_scaled.head()
# Out:
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
#           Date  country_code  Confirmed_lag_1  Confirmed_lag_2  \
# 825 2020-03-28            30         1.185099         0.390955
# 826 2020-03-29            30         1.178751         0.353930
# 827 2020-03-30            30         1.168795         0.393804
#
#      Confirmed_lag_3  Confirmed_lag_4  \
# 825        -0.471228        -1.104826
# 826        -0.372180        -1.160500
# 827        -0.422148        -1.140451
#
#      Case fatality rate of COVID-19 (%)_lag_1  \
# 825                                  1.069764
# 826                                  1.306912
# 827                                  1.218255
#
#      Case fatality rate of COVID-19 (%)_lag_2  \
# 825                                  0.452400
# 826                                  0.149917
# 827                                  0.376182
#
#      Case fatality rate of COVID-19 (%)_lag_3  \
# 825                                 -0.264873
# 826                                 -0.405667
# 827                                 -0.570034
#
#      Case fatality rate of COVID-19 (%)_lag_4  ...  \
# 825                                 -1.257291  ...
# 826                                 -1.051162  ...
# 827                                 -1.024403  ...
#
#      Population density (people per km²)_lag_3  \
# 825                               1.556376e-08
# 826                               1.556376e-08
# 827                               1.556376e-08
#
#      Population density (people per km²)_lag_4  Lockdown Level_lag_1  \
# 825                               1.556376e-08                   0.0
# 826                               1.556376e-08                   0.0
# 827                               1.556376e-08                   0.0
#
#      Lockdown Level_lag_2  Lockdown Level_lag_3  Lockdown Level_lag_4  \
# 825                   0.0                   0.0                   0.0
# 826                   0.0                   0.0                   0.0
# 827                   0.0                   0.0                   0.0
#
#      Country Temperature ºC_lag_1  Country Temperature ºC_lag_2  \
# 825                 -1.325606e-10                 -1.325606e-10
# 826                 -1.325606e-10                 -1.325606e-10
# 827                 -1.325606e-10                 -1.325606e-10
#
#      Country Temperature ºC_lag_3  Country Temperature ºC_lag_4
# 825                 -1.325606e-10                 -1.325606e-10
# 826                 -1.325606e-10                 -1.325606e-10
# 827                 -1.325606e-10                 -1.325606e-10
#
# [3 rows x 82 columns]

# %%
valid_sk_scaled = valid_sk[['Date', 'country_code']]
for col in tqdm_notebook(cols_list):
    feat_list = [col + '_lag_' + str(shift) for shift in range(1, N+1)]
    temp = valid_sk.apply(lambda row: scale_row(row[feat_list], row[col+'_mean'], row[col+'_std']), axis=1)
    valid_sk_scaled = pd.concat([valid_sk_scaled, temp], axis=1)
    
# Now the entire valid_sk set is scaled
valid_sk_scaled.head()
# Out:
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
#            Date  country_code  Confirmed_lag_1  Confirmed_lag_2  \
# 1152 2020-03-28            44         1.137212         0.424742
# 1153 2020-03-29            44         1.251784         0.242058
# 1154 2020-03-30            44         1.149046         0.457643
# 1155 2020-03-31            44         1.036192         0.488240
# 1156 2020-04-01            44         1.224600         0.261864
#
#       Confirmed_lag_3  Confirmed_lag_4  \
# 1152        -0.389510        -1.172444
# 1153        -0.387292        -1.106549
# 1154        -0.503737        -1.102953
# 1155        -0.249389        -1.275043
# 1156        -0.338883        -1.147581
#
#       Case fatality rate of COVID-19 (%)_lag_1  \
# 1152                                  1.262881
# 1153                                  1.055030
# 1154                                  1.187633
# 1155                                  1.183535
# 1156                                  1.001394
#
#       Case fatality rate of COVID-19 (%)_lag_2  \
# 1152                                  0.207063
# 1153                                  0.592229
# 1154                                  0.231383
# 1155                                  0.433991
# 1156                                  0.528888
#
#       Case fatality rate of COVID-19 (%)_lag_3  \
# 1152                                 -0.359547
# 1153                                 -0.524090
# 1154                                 -0.195122
# 1155                                 -0.582153
# 1156                                 -0.242358
#
#       Case fatality rate of COVID-19 (%)_lag_4  ...  \
# 1152                                 -1.110397  ...
# 1153                                 -1.123168  ...
# 1154                                 -1.223894  ...
# 1155                                 -1.035372  ...
# 1156                                 -1.287924  ...
#
#       Population density (people per km²)_lag_3  \
# 1152                               3.410605e-10
# 1153                               3.410605e-10
# 1154                               3.410605e-10
# 1155                               3.410605e-10
# 1156                               3.410605e-10
#
#       Population density (people per km²)_lag_4  Lockdown Level_lag_1  \
# 1152                               3.410605e-10                   0.0
# 1153                               3.410605e-10                   0.0
# 1154                               3.410605e-10                   0.0
# 1155                               3.410605e-10                   0.0
# 1156                               3.410605e-10                   0.0
#
#       Lockdown Level_lag_2  Lockdown Level_lag_3  Lockdown Level_lag_4  \
# 1152                   0.0                   0.0                   0.0
# 1153                   0.0                   0.0                   0.0
# 1154                   0.0                   0.0                   0.0
# 1155                   0.0                   0.0                   0.0
# 1156                   0.0                   0.0                   0.0
#
#       Country Temperature ºC_lag_1  Country Temperature ºC_lag_2  \
# 1152                 -1.073061e-07                 -1.073061e-07
# 1153                 -1.073061e-07                 -1.073061e-07
# 1154                 -1.073061e-07                 -1.073061e-07
# 1155                 -1.073061e-07                 -1.073061e-07
# 1156                 -1.073061e-07                 -1.073061e-07
#
#       Country Temperature ºC_lag_3  Country Temperature ºC_lag_4
# 1152                 -1.073061e-07                 -1.073061e-07
# 1153                 -1.073061e-07                 -1.073061e-07
# 1154                 -1.073061e-07                 -1.073061e-07
# 1155                 -1.073061e-07                 -1.073061e-07
# 1156                 -1.073061e-07                 -1.073061e-07
#
# [5 rows x 82 columns]

# %%
valid_lombardia_scaled = valid_lombardia[['Date', 'country_code']]
for col in tqdm_notebook(cols_list):
    feat_list = [col + '_lag_' + str(shift) for shift in range(1, N+1)]
    temp = valid_lombardia.apply(lambda row: scale_row(row[feat_list], row[col+'_mean'], row[col+'_std']), axis=1)
    valid_lombardia_scaled = pd.concat([valid_lombardia_scaled, temp], axis=1)
    
# Now the entire valid_lombardia set is scaled
valid_lombardia_scaled.head()
# Out:
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
#           Date  country_code  Confirmed_lag_1  Confirmed_lag_2  \
# 712 2020-03-28            25         1.205564         0.373175
# 713 2020-03-29            25         1.123434         0.429645
# 714 2020-03-30            25         1.075856         0.475887
# 715 2020-03-31            25         1.039549         0.491956
# 716 2020-04-01            25         1.082434         0.438600
#
#      Confirmed_lag_3  Confirmed_lag_4  \
# 712        -0.505514        -1.073225
# 713        -0.359840        -1.193239
# 714        -0.321937        -1.229806
# 715        -0.263476        -1.268029
# 716        -0.271031        -1.250003
#
#      Case fatality rate of COVID-19 (%)_lag_1  \
# 712                                  1.396479
# 713                                  1.300980
# 714                                  1.099755
# 715                                  1.209306
# 716                                  1.151138
#
#      Case fatality rate of COVID-19 (%)_lag_2  \
# 712                                 -0.083717
# 713                                  0.262922
# 714                                  0.477339
# 715                                  0.278865
# 716                                  0.451067
#
#      Case fatality rate of COVID-19 (%)_lag_3  \
# 712                                 -0.355413
# 713                                 -0.694117
# 714                                 -0.389127
# 715                                 -0.324272
# 716                                 -0.494599
#
#      Case fatality rate of COVID-19 (%)_lag_4  ...  \
# 712                                 -0.957350  ...
# 713                                 -0.869785  ...
# 714                                 -1.187967  ...
# 715                                 -1.163899  ...
# 716                                 -1.107606  ...
#
#      Population density (people per km²)_lag_3  \
# 712                                        0.0
# 713                                        0.0
# 714                                        0.0
# 715                                        0.0
# 716                                        0.0
#
#      Population density (people per km²)_lag_4  Lockdown Level_lag_1  \
# 712                                        0.0                   0.0
# 713                                        0.0                   0.0
# 714                                        0.0                   0.0
# 715                                        0.0                   0.0
# 716                                        0.0                   0.0
#
#      Lockdown Level_lag_2  Lockdown Level_lag_3  Lockdown Level_lag_4  \
# 712                   0.0                   0.0                   0.0
# 713                   0.0                   0.0                   0.0
# 714                   0.0                   0.0                   0.0
# 715                   0.0                   0.0                   0.0
# 716                   0.0                   0.0                   0.0
#
#      Country Temperature ºC_lag_1  Country Temperature ºC_lag_2  \
# 712                 -1.571008e-07                 -1.571008e-07
# 713                 -1.571008e-07                 -1.571008e-07
# 714                 -1.571008e-07                 -1.571008e-07
# 715                 -1.571008e-07                 -1.571008e-07
# 716                 -1.571008e-07                 -1.571008e-07
#
#      Country Temperature ºC_lag_3  Country Temperature ºC_lag_4
# 712                 -1.571008e-07                 -1.571008e-07
# 713                 -1.571008e-07                 -1.571008e-07
# 714                 -1.571008e-07                 -1.571008e-07
# 715                 -1.571008e-07                 -1.571008e-07
# 716                 -1.571008e-07                 -1.571008e-07
#
# [5 rows x 82 columns]

# %%
valid_wuhua_scaled = valid_wuhua[['Date', 'country_code']]
for col in tqdm_notebook(cols_list):
    feat_list = [col + '_lag_' + str(shift) for shift in range(1, N+1)]
    temp = valid_wuhua.apply(lambda row: scale_row(row[feat_list], row[col+'_mean'], row[col+'_std']), axis=1)
    valid_wuhua_scaled = pd.concat([valid_wuhua_scaled, temp], axis=1)
    
# Now the entire valid_wuhua set is scaled
valid_wuhua_scaled.head()
# Out:
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
#            Date  country_code  Confirmed_lag_1  Confirmed_lag_2  \
# 1437 2020-03-28            53              0.0              0.0
# 1438 2020-03-29            53              0.0              0.0
# 1439 2020-03-30            53              0.0              0.0
# 1440 2020-03-31            53              0.0              0.0
# 1441 2020-04-01            53              0.0              0.0
#
#       Confirmed_lag_3  Confirmed_lag_4  \
# 1437              0.0              0.0
# 1438              0.0              0.0
# 1439              0.0              0.0
# 1440              0.0              0.0
# 1441              0.0              0.0
#
#       Case fatality rate of COVID-19 (%)_lag_1  \
# 1437                                  1.200961
# 1438                                  1.019489
# 1439                                  1.193381
# 1440                                  1.175901
# 1441                                  0.879883
#
#       Case fatality rate of COVID-19 (%)_lag_2  \
# 1437                                  0.400320
# 1438                                  0.530134
# 1439                                  0.275396
# 1440                                  0.423324
# 1441                                  0.659912
#
#       Case fatality rate of COVID-19 (%)_lag_3  \
# 1437                                 -0.560449
# 1438                                 -0.285457
# 1439                                 -0.275396
# 1440                                 -0.517396
# 1441                                 -0.219971
#
#       Case fatality rate of COVID-19 (%)_lag_4  ...  \
# 1437                                 -1.040833  ...
# 1438                                 -1.264166  ...
# 1439                                 -1.193381  ...
# 1440                                 -1.081829  ...
# 1441                                 -1.319824  ...
#
#       Population density (people per km²)_lag_3  \
# 1437                                        0.0
# 1438                                        0.0
# 1439                                        0.0
# 1440                                        0.0
# 1441                                        0.0
#
#       Population density (people per km²)_lag_4  Lockdown Level_lag_1  \
# 1437                                        0.0                   0.0
# 1438                                        0.0                   0.0
# 1439                                        0.0                   0.0
# 1440                                        0.0                   0.0
# 1441                                        0.0                   0.0
#
#       Lockdown Level_lag_2  Lockdown Level_lag_3  Lockdown Level_lag_4  \
# 1437                   0.0                   0.0                   0.0
# 1438                   0.0                   0.0                   0.0
# 1439                   0.0                   0.0                   0.0
# 1440                   0.0                   0.0                   0.0
# 1441                   0.0                   0.0                   0.0
#
#       Country Temperature ºC_lag_1  Country Temperature ºC_lag_2  \
# 1437                 -1.060366e-07                 -1.060366e-07
# 1438                 -1.060366e-07                 -1.060366e-07
# 1439                 -1.060366e-07                 -1.060366e-07
# 1440                 -1.060366e-07                 -1.060366e-07
# 1441                 -1.060366e-07                 -1.060366e-07
#
#       Country Temperature ºC_lag_3  Country Temperature ºC_lag_4
# 1437                 -1.060366e-07                 -1.060366e-07
# 1438                 -1.060366e-07                 -1.060366e-07
# 1439                 -1.060366e-07                 -1.060366e-07
# 1440                 -1.060366e-07                 -1.060366e-07
# 1441                 -1.060366e-07                 -1.060366e-07
#
# [5 rows x 82 columns]

# %% [markdown]
# # Split into X and y

# %%
features = ['country_code']
for i in range(1,N+1):
    for col in lag_cols:
        features.append(col + "_lag_" + str(i))
    
target = "Confirmed"


# Split into X and y
X_train = train[features]
y_train = train[target]
X_valid = valid[features]
y_valid = valid[target]
X_valid_br = valid_br[features]
y_valid_br = valid_br[target]
X_valid_sk = valid_sk[features]
y_valid_sk = valid_sk[target]
X_valid_sp = valid_sp[features]
y_valid_sp = valid_sp[target]
X_valid_nyc = valid_nyc[features]
y_valid_nyc = valid_nyc[target]
X_valid_lombardia = valid_lombardia[features]
y_valid_lombardia = valid_lombardia[target]
X_valid_wuhua = valid_wuhua[features]
y_valid_wuhua = valid_wuhua[target]

print("X_train.shape = " + str(X_train.shape))
print("y_train.shape = " + str(y_train.shape))
print("X_valid.shape = " + str(X_valid.shape))
print("y_valid_br.shape = " + str(y_valid_br.shape))
print("X_valid_br.shape = " + str(X_valid_br.shape))
print("y_valid.shape = " + str(y_valid.shape))
# Out:
# X_train.shape = (1175, 81)
# y_train.shape = (1175,)
# X_valid.shape = (268, 81)
# y_valid_br.shape = (5,)
# X_valid_br.shape = (5, 81)
# y_valid.shape = (268,)

# %%
# Split into X and y
X_train_scaled = train_scaled[features]
y_train_scaled = train_scaled[target]
X_valid_scaled = valid_scaled[features]
X_valid_br_scaled = valid_br_scaled[features]
X_valid_sk_scaled = valid_sk_scaled[features]
X_valid_sp_scaled = valid_sp_scaled[features]
X_valid_nyc_scaled = valid_nyc_scaled[features]
X_valid_lombardia_scaled = valid_lombardia_scaled[features]
X_valid_wuhua_scaled = valid_wuhua_scaled[features]


print("X_train_scaled.shape = " + str(X_train_scaled.shape))
print("y_train_scaled.shape = " + str(y_train_scaled.shape))
print("X_valid_scaled.shape = " + str(X_valid_scaled.shape))
print("X_valid_br_scaled.shape = " + str(X_valid_br_scaled.shape))
print("X_valid_sk_scaled.shape = " + str(X_valid_sk_scaled.shape))
print("X_valid_sp_scaled.shape = " + str(X_valid_sp_scaled.shape))
print("X_valid_nyc_scaled.shape = " + str(X_valid_nyc_scaled.shape))
print("X_valid_lombardia_scaled.shape = " + str(X_valid_lombardia_scaled.shape))
print("X_valid_wuhua_scaled.shape = " + str(X_valid_wuhua_scaled.shape))
# Out:
# X_train_scaled.shape = (1175, 81)
# y_train_scaled.shape = (1175,)
# X_valid_scaled.shape = (268, 81)
# X_valid_br_scaled.shape = (5, 81)
# X_valid_sk_scaled.shape = (5, 81)
# X_valid_sp_scaled.shape = (4, 81)
# X_valid_nyc_scaled.shape = (3, 81)
# X_valid_lombardia_scaled.shape = (5, 81)
# X_valid_wuhua_scaled.shape = (6, 81)

# %% [markdown]
# # EDA

# %%
mask_train = (train['Country'] == 'Brazil')
mask_valid = (valid['Country'] == 'Brazil')

ax = train.loc[mask_train].plot(x='Date', y='Confirmed', style='b-', grid=True)
ax = valid.loc[mask_valid].plot(x='Date', y='Confirmed', style='y-', grid=True, ax=ax)
ax.legend(['train', 'validation'])
ax.set_xlabel("date")
ax.set_ylabel("Confirmed")
ax.set_title("Without scaling")
# Out:
# Text(0.5, 1.0, 'Without scaling')

# %%
code = valid[valid['Country'] == 'Brazil']['country_code'].unique()
ax = train_scaled[train_scaled['country_code'] ==  code[0]].plot(x='Date', y='Confirmed', style='b-', grid=True)
ax.legend(['train_scaled'])
ax.set_xlabel("date")
ax.set_ylabel("Confirmed (scaled)")
ax.set_title("With scaling")
# Out:
# Text(0.5, 1.0, 'With scaling')

# %% [markdown]
# # Train the model using XGBoost

# %%
n_estimators = 100             # Number of boosted trees to fit. default = 100
max_depth = 3                  # Maximum tree depth for base learners. default = 3
learning_rate = 0.1            # Boosting learning rate (xgb’s “eta”). default = 0.1
min_child_weight = 1           # Minimum sum of instance weight(hessian) needed in a child. default = 1
subsample = 1                  # Subsample ratio of the training instance. default = 1
colsample_bytree = 1           # Subsample ratio of columns when constructing each tree. default = 1
colsample_bylevel = 1          # Subsample ratio of columns for each split, in each level. default = 1
gamma = 0  
model_seed = 100

# %%
X_train_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1175 entries, 0 to 1174
# Data columns (total 81 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   country_code                                                         1175 non-null   int64
#  1   Confirmed_lag_1                                                      1121 non-null   float64
#  2   Case fatality rate of COVID-19 (%)_lag_1                             951 non-null    float64
#  3   Daily new confirmed cases of COVID-19 (rolling 3-day average)_lag_1  1121 non-null   float64
#  4   Age 0-9_lag_1                                                        995 non-null    float64
#  5   Age 10-19_lag_1                                                      995 non-null    float64
#  6   Age 20-29_lag_1                                                      995 non-null    float64
#  7   Age 30-39_lag_1                                                      995 non-null    float64
#  8   Age 40-49_lag_1                                                      995 non-null    float64
#  9   Age 50-59_lag_1                                                      995 non-null    float64
#  10  Age 60-69_lag_1                                                      995 non-null    float64
#  11  Age 70-79_lag_1                                                      995 non-null    float64
#  12  Age >80_lag_1                                                        995 non-null    float64
#  13  # People_lag_1                                                       995 non-null    float64
#  14  GDP_lag_1                                                            1089 non-null   float64
#  15  GDP per capta_lag_1                                                  1121 non-null   float64
#  16  Life expectancy_lag_1                                                995 non-null    float64
#  17  # Flight Passengers_lag_1                                            925 non-null    float64
#  18  Population density (people per km²)_lag_1                            1121 non-null   float64
#  19  Lockdown Level_lag_1                                                 1121 non-null   float64
#  20  Country Temperature ºC_lag_1                                         1121 non-null   float64
#  21  Confirmed_lag_2                                                      1067 non-null   float64
#  22  Case fatality rate of COVID-19 (%)_lag_2                             897 non-null    float64
#  23  Daily new confirmed cases of COVID-19 (rolling 3-day average)_lag_2  1067 non-null   float64
#  24  Age 0-9_lag_2                                                        945 non-null    float64
#  25  Age 10-19_lag_2                                                      945 non-null    float64
#  26  Age 20-29_lag_2                                                      945 non-null    float64
#  27  Age 30-39_lag_2                                                      945 non-null    float64
#  28  Age 40-49_lag_2                                                      945 non-null    float64
#  29  Age 50-59_lag_2                                                      945 non-null    float64
#  30  Age 60-69_lag_2                                                      945 non-null    float64
#  31  Age 70-79_lag_2                                                      945 non-null    float64
#  32  Age >80_lag_2                                                        945 non-null    float64
#  33  # People_lag_2                                                       945 non-null    float64
#  34  GDP_lag_2                                                            1036 non-null   float64
#  35  GDP per capta_lag_2                                                  1067 non-null   float64
#  36  Life expectancy_lag_2                                                945 non-null    float64
#  37  # Flight Passengers_lag_2                                            879 non-null    float64
#  38  Population density (people per km²)_lag_2                            1067 non-null   float64
#  39  Lockdown Level_lag_2                                                 1067 non-null   float64
#  40  Country Temperature ºC_lag_2                                         1067 non-null   float64
#  41  Confirmed_lag_3                                                      1013 non-null   float64
#  42  Case fatality rate of COVID-19 (%)_lag_3                             843 non-null    float64
#  43  Daily new confirmed cases of COVID-19 (rolling 3-day average)_lag_3  1013 non-null   float64
#  44  Age 0-9_lag_3                                                        895 non-null    float64
#  45  Age 10-19_lag_3                                                      895 non-null    float64
#  46  Age 20-29_lag_3                                                      895 non-null    float64
#  47  Age 30-39_lag_3                                                      895 non-null    float64
#  48  Age 40-49_lag_3                                                      895 non-null    float64
#  49  Age 50-59_lag_3                                                      895 non-null    float64
#  50  Age 60-69_lag_3                                                      895 non-null    float64
#  51  Age 70-79_lag_3                                                      895 non-null    float64
#  52  Age >80_lag_3                                                        895 non-null    float64
#  53  # People_lag_3                                                       895 non-null    float64
#  54  GDP_lag_3                                                            983 non-null    float64
#  55  GDP per capta_lag_3                                                  1013 non-null   float64
#  56  Life expectancy_lag_3                                                895 non-null    float64
#  57  # Flight Passengers_lag_3                                            833 non-null    float64
#  58  Population density (people per km²)_lag_3                            1013 non-null   float64
#  59  Lockdown Level_lag_3                                                 1013 non-null   float64
#  60  Country Temperature ºC_lag_3                                         1013 non-null   float64
#  61  Confirmed_lag_4                                                      959 non-null    float64
#  62  Case fatality rate of COVID-19 (%)_lag_4                             789 non-null    float64
#  63  Daily new confirmed cases of COVID-19 (rolling 3-day average)_lag_4  959 non-null    float64
#  64  Age 0-9_lag_4                                                        845 non-null    float64
#  65  Age 10-19_lag_4                                                      845 non-null    float64
#  66  Age 20-29_lag_4                                                      845 non-null    float64
#  67  Age 30-39_lag_4                                                      845 non-null    float64
#  68  Age 40-49_lag_4                                                      845 non-null    float64
#  69  Age 50-59_lag_4                                                      845 non-null    float64
#  70  Age 60-69_lag_4                                                      845 non-null    float64
#  71  Age 70-79_lag_4                                                      845 non-null    float64
#  72  Age >80_lag_4                                                        845 non-null    float64
#  73  # People_lag_4                                                       845 non-null    float64
#  74  GDP_lag_4                                                            930 non-null    float64
#  75  GDP per capta_lag_4                                                  959 non-null    float64
#  76  Life expectancy_lag_4                                                845 non-null    float64
#  77  # Flight Passengers_lag_4                                            787 non-null    float64
#  78  Population density (people per km²)_lag_4                            959 non-null    float64
#  79  Lockdown Level_lag_4                                                 959 non-null    float64
#  80  Country Temperature ºC_lag_4                                         959 non-null    float64
# dtypes: float64(80), int64(1)
# memory usage: 743.7 KB

# %%
# Create the model
model = XGBRegressor(seed=model_seed,
                     n_estimators=n_estimators,
                     max_depth=max_depth,
                     learning_rate=learning_rate,
                     min_child_weight=min_child_weight,
                     subsample=subsample,
                     colsample_bytree=colsample_bytree,
                     colsample_bylevel=colsample_bylevel,
                     gamma=gamma)

# Train the regressor
model.fit(X_train_scaled, y_train_scaled)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints=None,
#              learning_rate=0.1, max_delta_step=0, max_depth=3,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=100, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, seed=100, subsample=1,
#              tree_method=None, validate_parameters=False, verbosity=None)

# %% [markdown]
# # Predict on train set

# %%
def get_mape(y_true, y_pred): 
    """
    Compute mean absolute percentage error (MAPE)
    """
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
# Do prediction on train set
est_scaled = model.predict(X_train_scaled)
est = est_scaled * math.sqrt(scaler.var_[0]) + scaler.mean_[0]

# Calculate RMSE
print("RMSE on train set = %0.3f" % math.sqrt(mean_squared_error(y_train, est)))

# Calculate MAPE
print("MAPE on train set = %0.3f%%" % get_mape(y_train, est))
# Out:
# RMSE on train set = 300.518
# MAPE on train set = 16.934%

# %%
est_df = pd.DataFrame({'est': est, 
                       'Date': train['Date'], 
                       'Country': train['Country']})

country = 'Brazil'
mask_train = (train['Country'] == country)
mask_valid = (valid['Country'] == country)
mask_est = (est_df['Country'] == country)

ax = train.loc[mask_train].plot(x='Date', y='Confirmed', style='b-', grid=True)
ax = valid.loc[mask_valid].plot(x='Date', y='Confirmed', style='y-', grid=True, ax=ax)
ax = est_df.loc[mask_est].plot(x='Date', y='est', style='r-', grid=True, ax=ax)
ax.legend(['train', 'validation', 'predictions'])
ax.set_xlabel("Date")
ax.set_ylabel("Confirmed")
# Out:
# Text(0, 0.5, 'Confirmed')

# %% [markdown]
# # Predict on valid set brasil

# %%
# Do prediction on test set
est_scaled_br = model.predict(X_valid_br_scaled)
valid_br['est_scaled_br'] = est_scaled_br
valid_br['est'] = valid_br['est_scaled_br'] * valid_br['Confirmed_std'] + valid_br['Confirmed_mean']

# Calculate RMSE
rmse_bef_tuning = math.sqrt(mean_squared_error(y_valid_br, valid_br['est']))
print("RMSE on dev set = %0.3f" % rmse_bef_tuning)

# Calculate MAPE
mape_bef_tuning = get_mape(y_valid_br, valid_br['est'])
print("MAPE on dev set = %0.3f%%" % mape_bef_tuning)
# Out:
# RMSE on dev set = 781.893
# MAPE on dev set = 12.374%
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
est_df = pd.DataFrame({'est': valid_br['est'], 
                       'y_valid_br': y_valid_br,
                       'Date': valid_br['Date']})

country = 'Brazil'
mask_train = (train['Country'] == country)

ax = train.loc[mask_train].plot(x='Date', y='Confirmed', style='b-', grid=True)
ax = valid_br.plot(x='Date', y='Confirmed', style='y-', grid=True, ax=ax)
ax = est_df.plot(x='Date', y='est', style='r-', grid=True, ax=ax)
ax.legend(['train', 'validation', 'predictions'])
ax.set_xlabel("Date")
ax.set_ylabel("Confirmed")
# Out:
# Text(0, 0.5, 'Confirmed')

# %%
est_df = pd.DataFrame({'est': valid_br['est'], 
                       'y_valid_br': y_valid_br,
                       'Date': valid_br['Date']})

ax = valid_br.plot(x='Date', y='Confirmed', style='y-', grid=True)
ax = est_df.plot(x='Date', y='est', style='r-', grid=True, ax=ax)
ax.legend(['validation', 'predictions'])
ax.set_xlabel("Date")
ax.set_ylabel("Confirmed")
ax.set_title("Brazil")
# Out:
# Text(0.5, 1.0, 'Brazil')

# %% [markdown]
# # Predict on valid set Koreia do Sul

# %%
# Do prediction on test set
est_scaled_sk = model.predict(X_valid_sk_scaled)
valid_sk['est_scaled_sk'] = est_scaled_sk
valid_sk['est'] = valid_sk['est_scaled_sk'] * valid_sk['Confirmed_std'] + valid_sk['Confirmed_mean']

# Calculate RMSE
rmse_bef_tuning = math.sqrt(mean_squared_error(y_valid_sk, valid_sk['est']))
print("RMSE on dev set = %0.3f" % rmse_bef_tuning)

# Calculate MAPE
mape_bef_tuning = get_mape(y_valid_sk, valid_sk['est'])
print("MAPE on dev set = %0.3f%%" % mape_bef_tuning)
# Out:
# RMSE on dev set = 102.078
# MAPE on dev set = 1.016%
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
est_df = pd.DataFrame({'est': valid_sk['est'], 
                       'y_valid_sk': y_valid_sk,
                       'Date': valid_sk['Date']})

country = 'South Korea'
mask_train = (train['Country'] == country)

ax = train.loc[mask_train].plot(x='Date', y='Confirmed', style='b-', grid=True)
ax = valid_sk.plot(x='Date', y='Confirmed', style='y-', grid=True, ax=ax)
ax = est_df.plot(x='Date', y='est', style='r-', grid=True, ax=ax)
ax.legend(['train', 'validation', 'predictions'])
ax.set_xlabel("Date")
ax.set_ylabel("Confirmed")
# Out:
# Text(0, 0.5, 'Confirmed')

# %%
est_df = pd.DataFrame({'est': valid_sk['est'], 
                       'y_valid_sk': y_valid_sk,
                       'Date': valid_sk['Date']})

ax = valid_sk.plot(x='Date', y='Confirmed', style='y-', grid=True)
ax = est_df.plot(x='Date', y='est', style='r-', grid=True, ax=ax)
ax.legend(['validation', 'predictions'])
ax.set_xlabel("Date")
ax.set_ylabel("Confirmed")
ax.set_title("South Korea")
# Out:
# Text(0.5, 1.0, 'South Korea')

# %% [markdown]
# ## Predict on valid set NYC

# %%
# Do prediction on test set
est_scaled_nyc = model.predict(X_valid_nyc_scaled)
valid_nyc['est_scaled_nyc'] = est_scaled_nyc
valid_nyc['est'] = valid_nyc['est_scaled_nyc'] * valid_nyc['Confirmed_std'] + valid_nyc['Confirmed_mean']

# Calculate RMSE
rmse_bef_tuning = math.sqrt(mean_squared_error(y_valid_nyc, valid_nyc['est']))
print("RMSE on dev set = %0.3f" % rmse_bef_tuning)

# Calculate MAPE
mape_bef_tuning = get_mape(y_valid_nyc, valid_nyc['est'])
print("MAPE on dev set = %0.3f%%" % mape_bef_tuning)
# Out:
# RMSE on dev set = 3447.011
# MAPE on dev set = 10.373%
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
est_df = pd.DataFrame({'est': valid_nyc['est'], 
                       'y_valid_nyc': y_valid_nyc,
                       'Date': valid_nyc['Date']})

country = 'New York'
mask_nyc_train = (train['Country'] == country)

ax = train.loc[mask_nyc_train].plot(x='Date', y='Confirmed', style='b-', grid=True)
ax = valid_nyc.plot(x='Date', y='Confirmed', style='y-', grid=True, ax=ax)
ax = est_df.plot(x='Date', y='est', style='r-', grid=True, ax=ax)
ax.legend(['train', 'validation', 'predictions'])
ax.set_xlabel("Date")
ax.set_ylabel("Confirmed")
# Out:
# Text(0, 0.5, 'Confirmed')

# %%
est_df = pd.DataFrame({'est': valid_nyc['est'], 
                       'y_valid_nyc': y_valid_nyc,
                       'Date': valid_nyc['Date']})

ax = valid_nyc.plot(x='Date', y='Confirmed', style='y-', grid=True)
ax = est_df.plot(x='Date', y='est', style='r-', grid=True, ax=ax)
ax.legend(['validation', 'predictions'])
ax.set_xlabel("Date")
ax.set_ylabel("Confirmed")
ax.set_title("New York")
# Out:
# Text(0.5, 1.0, 'New York')

# %% [markdown]
# # Predict on valid set Lombardia

# %%
# Do prediction on test set
est_scaled_lombardia = model.predict(X_valid_lombardia_scaled)
valid_lombardia['est_scaled_lombardia'] = est_scaled_lombardia
valid_lombardia['est'] = valid_lombardia['est_scaled_lombardia'] * valid_lombardia['Confirmed_std'] + valid_lombardia['Confirmed_mean']

# Calculate RMSE
rmse_bef_tuning = math.sqrt(mean_squared_error(y_valid_lombardia, valid_lombardia['est']))
print("RMSE on dev set = %0.3f" % rmse_bef_tuning)

# Calculate MAPE
mape_bef_tuning = get_mape(y_valid_lombardia, valid_lombardia['est'])
print("MAPE on dev set = %0.3f%%" % mape_bef_tuning)

est_df = pd.DataFrame({'est': valid_lombardia['est'], 
                       'y_valid_lombardia': y_valid_lombardia,
                       'Date': valid_lombardia['Date']})

ax = valid_lombardia.plot(x='Date', y='Confirmed', style='y-', grid=True)
ax = est_df.plot(x='Date', y='est', style='r-', grid=True, ax=ax)
ax.legend(['validation', 'predictions'])
ax.set_xlabel("Date")
ax.set_ylabel("Confirmed")
ax.set_title("Lombardia")
# Out:
# RMSE on dev set = 1351.584
# MAPE on dev set = 3.120%
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# Text(0.5, 1.0, 'Lombardia')

# %% [markdown]
# # Predict Wuhan

# %%
# Do prediction on test set
est_scaled_wuhua = model.predict(X_valid_wuhua_scaled)
valid_wuhua['est_scaled_wuhua'] = est_scaled_wuhua
valid_wuhua['est'] = valid_wuhua['est_scaled_wuhua'] * valid_wuhua['Confirmed_std'] + valid_wuhua['Confirmed_mean']

# Calculate RMSE
rmse_bef_tuning = math.sqrt(mean_squared_error(y_valid_wuhua, valid_wuhua['est']))
print("RMSE on dev set = %0.3f" % rmse_bef_tuning)

# Calculate MAPE
mape_bef_tuning = get_mape(y_valid_wuhua, valid_wuhua['est'])
print("MAPE on dev set = %0.3f%%" % mape_bef_tuning)

est_df = pd.DataFrame({'est': valid_wuhua['est'], 
                       'y_valid_wuhua': y_valid_wuhua,
                       'Date': valid_wuhua['Date']})

ax = valid_wuhua.plot(x='Date', y='Confirmed', style='y-', grid=True)
ax = est_df.plot(x='Date', y='est', style='r-', grid=True, ax=ax)
ax.legend(['validation', 'predictions'])
ax.set_xlabel("Date")
ax.set_ylabel("Confirmed")
ax.set_title("Wuhan")
# Out:
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# RMSE on dev set = 0.408
# MAPE on dev set = 0.000%
# Text(0.5, 1.0, 'Wuhan')

# %%
_ = plot_importance(model, height=0.7)

# %% [markdown]
# # Predicting Deats

# %% [markdown]
# ## Feature Engeneering

# %%
# Add a column 'order_day' to indicate the order of the rows by date
for country in df_deaths['Country'].unique():
    df_deaths.loc[df_deaths['Country'] == country, 'order_day'] = [x for x in list(range(len( df_deaths.loc[df_deaths['Country'] == country, :])))]

# merging_keys
merging_keys = ['Country', 'country_code','order_day']

# List of columns that we will use to create lags
lag_cols = df_deaths.columns.values.tolist()[2:22]
lag_cols
# Out:
# ['Confirmed',
#  'Deaths',
#  'Case fatality rate of COVID-19 (%)',
#  'Daily new confirmed cases of COVID-19 (rolling 3-day average)',
#  'Daily new confirmed deaths due to COVID-19 (rolling 3-day average)',
#  'Age 0-9',
#  'Age 10-19',
#  'Age 20-29',
#  'Age 30-39',
#  'Age 40-49',
#  'Age 50-59',
#  'Age 60-69',
#  'Age 70-79',
#  'Age >80',
#  '# People',
#  'GDP',
#  'GDP per capta',
#  'Life expectancy',
#  '# Flight Passengers',
#  'Hospital beds (per 1,000 people)']

# %%
N = 4
shift_range = [x+1 for x in range(N)]

for shift in tqdm_notebook(shift_range):
    train_shift = df_deaths[merging_keys + lag_cols].copy()
    
    for country in df_deaths['Country'].unique():    
        # E.g. order_day of 0 becomes 1, for shift = 1.
        # So when this is merged with order_day of 1 in df_deaths, this will represent lag of 1.

        train_shift.loc[train_shift['Country'] == country, 'order_day'] =train_shift.loc[train_shift['Country'] == country, 'order_day'] + shift

    foo = lambda x: '{}_lag_{}'.format(x, shift) if x in lag_cols else x
    train_shift = train_shift.rename(columns=foo)

    df_deaths = pd.merge(df_deaths, train_shift, on=merging_keys, how='left')
    
del train_shift
# Out:
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   after removing the cwd from sys.path.
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))

# %% [markdown]
# # Get mean and std dev at timestamp t using values from t-1, ..., t-N

# %%
cols_list = lag_cols

for col in cols_list:
    df_deaths = get_mov_avg_std(df_deaths, col, N)

# %% [markdown]
# # Split into train, validation and test set

# %%
valid_date = dt.datetime.today() - dt.timedelta(days=7)

mask_valid = (df_deaths['Date'] >= valid_date )
mask_valid_br = ((df_deaths['Date'] >= valid_date ) & (df_deaths['Country'] == 'Brazil'))
mask_valid_sp = ((df_deaths['Date'] >= valid_date ) & (df_deaths['Country'] == 'São Paulo'))
mask_valid_nyc = ((df_deaths['Date'] >= valid_date ) & (df_deaths['Country'] == 'New York'))
mask_valid_sk = ((df_deaths['Date'] >= valid_date ) & (df_deaths['Country'] == 'South Korea'))
mask_valid_lombardia = ((df_deaths['Date'] >= valid_date ) & (df_deaths['Country'] == 'Lombardia'))
mask_valid_wuhua = ((df_deaths['Date'] >= valid_date ) & (df_deaths['Country'] == 'Wuhan'))


mask_train = (df_deaths['Date'] < valid_date )

# Split into train, valid, and test
train = df_deaths.loc[mask_train]
valid = df_deaths.loc[mask_valid]
valid_br = df_deaths.loc[mask_valid_br]
valid_sp = df_deaths.loc[mask_valid_sp]
valid_nyc = df_deaths.loc[mask_valid_nyc]
valid_sk = df_deaths.loc[mask_valid_sk]
valid_lombardia = df_deaths.loc[mask_valid_lombardia]
valid_wuhua = df_deaths.loc[mask_valid_wuhua]

print("train.shape = " + str(train.shape))
print("valid.shape = " + str(valid.shape))
print("valid_br.shape = " + str(valid_br.shape))
print("valid_sp.shape = " + str(valid_sp.shape))
print("valid_nyc.shape = " + str(valid_nyc.shape))
print("valid_sk.shape = " + str(valid_sk.shape))
print("valid_lombardia.shape = " + str(valid_lombardia.shape))
print("valid_wuhua.shape = " + str(valid_wuhua.shape))
# Out:
# train.shape = (1175, 147)
# valid.shape = (268, 147)
# valid_br.shape = (5, 147)
# valid_sp.shape = (4, 147)
# valid_nyc.shape = (3, 147)
# valid_sk.shape = (5, 147)
# valid_lombardia.shape = (5, 147)
# valid_wuhua.shape = (6, 147)

# %% [markdown]
# # Scale the train, validation and test set

# %%
cols_to_scale = ['Deaths']

for i in range(1,N+1):
    for col in lag_cols:
        print(col + "_lag_"+ str(i))
        cols_to_scale.append(col + "_lag_" + str(i))

# Do scaling for train set
# Here we only scale the train dataset, and not the entire dataset to prevent information leak
scaler = StandardScaler()
train_scaled = scaler.fit_transform(train[cols_to_scale])
print("scaler.mean_ = " + str(scaler.mean_))
print("scaler.var_ = " + str(scaler.var_))
print("train_scaled.shape = " + str(train_scaled.shape))

# Convert the numpy array back into pandas dataframe
train_scaled = pd.DataFrame(train_scaled, columns=cols_to_scale)
train_scaled[['Date', 'country_code']] = train.reset_index()[['Date', 'country_code']]
print("train_scaled.shape = " + str(train_scaled.shape))
train_scaled.head()
# Out:
# Confirmed_lag_1
# Deaths_lag_1
# Case fatality rate of COVID-19 (%)_lag_1
# Daily new confirmed cases of COVID-19 (rolling 3-day average)_lag_1
# Daily new confirmed deaths due to COVID-19 (rolling 3-day average)_lag_1
# Age 0-9_lag_1
# Age 10-19_lag_1
# Age 20-29_lag_1
# Age 30-39_lag_1
# Age 40-49_lag_1
# Age 50-59_lag_1
# Age 60-69_lag_1
# Age 70-79_lag_1
# Age >80_lag_1
# # People_lag_1
# GDP_lag_1
# GDP per capta_lag_1
# Life expectancy_lag_1
# # Flight Passengers_lag_1
# Hospital beds (per 1,000 people)_lag_1
# Confirmed_lag_2
# Deaths_lag_2
# Case fatality rate of COVID-19 (%)_lag_2
# Daily new confirmed cases of COVID-19 (rolling 3-day average)_lag_2
# Daily new confirmed deaths due to COVID-19 (rolling 3-day average)_lag_2
# Age 0-9_lag_2
# Age 10-19_lag_2
# Age 20-29_lag_2
# Age 30-39_lag_2
# Age 40-49_lag_2
# Age 50-59_lag_2
# Age 60-69_lag_2
# Age 70-79_lag_2
# Age >80_lag_2
# # People_lag_2
# GDP_lag_2
# GDP per capta_lag_2
# Life expectancy_lag_2
# # Flight Passengers_lag_2
# Hospital beds (per 1,000 people)_lag_2
# Confirmed_lag_3
# Deaths_lag_3
# Case fatality rate of COVID-19 (%)_lag_3
# Daily new confirmed cases of COVID-19 (rolling 3-day average)_lag_3
# Daily new confirmed deaths due to COVID-19 (rolling 3-day average)_lag_3
# Age 0-9_lag_3
# Age 10-19_lag_3
# Age 20-29_lag_3
# Age 30-39_lag_3
# Age 40-49_lag_3
# Age 50-59_lag_3
# Age 60-69_lag_3
# Age 70-79_lag_3
# Age >80_lag_3
# # People_lag_3
# GDP_lag_3
# GDP per capta_lag_3
# Life expectancy_lag_3
# # Flight Passengers_lag_3
# Hospital beds (per 1,000 people)_lag_3
# Confirmed_lag_4
# Deaths_lag_4
# Case fatality rate of COVID-19 (%)_lag_4
# Daily new confirmed cases of COVID-19 (rolling 3-day average)_lag_4
# Daily new confirmed deaths due to COVID-19 (rolling 3-day average)_lag_4
# Age 0-9_lag_4
# Age 10-19_lag_4
# Age 20-29_lag_4
# Age 30-39_lag_4
# Age 40-49_lag_4
# Age 50-59_lag_4
# Age 60-69_lag_4
# Age 70-79_lag_4
# Age >80_lag_4
# # People_lag_4
# GDP_lag_4
# GDP per capta_lag_4
# Life expectancy_lag_4
# # Flight Passengers_lag_4
# Hospital beds (per 1,000 people)_lag_4
# scaler.mean_ = [3.93010213e+02 9.28392864e+03 3.79911686e+02 2.10323361e+00
#  4.14191793e+02 1.24380761e+02 2.24686740e+07 2.23420778e+07
#  2.42006680e+07 2.59616415e+07 2.46639972e+07 2.28268516e+07
#  1.64453453e+07 8.45316348e+06 2.83920633e+06 1.70201625e+04
#  3.12753929e+06 3.37161341e+04 7.93690864e+01 1.24027889e+08
#  7.77448723e+00 9.15256232e+03 3.69071228e+02 2.08250776e+00
#  3.89306779e+02 1.23330366e+02 2.28078556e+07 2.26741322e+07
#  2.46076358e+07 2.64569924e+07 2.51813941e+07 2.33434521e+07
#  1.68156441e+07 8.63639086e+06 2.89741792e+06 1.73420915e+04
#  3.18507845e+06 3.38166620e+04 7.94184550e+01 1.26229759e+08
#  7.80936093e+00 9.07344620e+03 3.60266535e+02 2.06216261e+00
#  3.68219151e+02 1.23296644e+02 2.31849345e+07 2.30432878e+07
#  2.50600748e+07 2.70076898e+07 2.57566008e+07 2.39177734e+07
#  1.72273172e+07 8.84009057e+06 2.96213359e+06 1.76999902e+04
#  3.24882224e+06 3.39279076e+04 7.94733397e+01 1.28674813e+08
#  7.84813114e+00 9.04094891e+03 3.53498436e+02 2.03785376e+00
#  3.50906500e+02 1.23942475e+02 2.36066382e+07 2.34561303e+07
#  2.55660569e+07 2.76235585e+07 2.63998793e+07 2.45600616e+07
#  1.76877090e+07 9.06789675e+06 3.03450793e+06 1.81002438e+04
#  3.31983145e+06 3.40516814e+04 7.95347195e+01 1.31405692e+08
#  7.89148954e+00]
# scaler.var_ = [1.02989800e+06 4.17205091e+08 9.42352778e+05 5.88395322e+00
#  1.28215598e+06 2.81346919e+05 2.54936199e+15 2.57039621e+15
#  2.99174395e+15 3.52839540e+15 3.25564981e+15 2.87970477e+15
#  1.37490924e+15 2.81640611e+14 2.33640155e+13 1.43856327e+09
#  3.44046439e+13 5.71666371e+08 1.81488189e+01 4.30395069e+16
#  2.25583320e+01 4.13105464e+08 8.73134381e+05 5.76085231e+00
#  1.08961844e+06 2.82155899e+05 2.59448106e+15 2.61112642e+15
#  3.05191683e+15 3.61521202e+15 3.34550190e+15 2.96481442e+15
#  1.41530638e+15 2.89624071e+14 2.39814909e+13 1.47360457e+09
#  3.52852173e+13 5.67465089e+08 1.79328246e+01 4.39741065e+16
#  2.25533275e+01 4.13194995e+08 8.16962965e+05 5.62020820e+00
#  9.46603221e+05 2.86835241e+05 2.64437127e+15 2.65614864e+15
#  3.11842412e+15 3.71115276e+15 3.44476486e+15 3.05880700e+15
#  1.45989525e+15 2.98420721e+14 2.46600026e+13 1.51231778e+09
#  3.62530146e+13 5.62792334e+08 1.76869749e+01 4.50005653e+16
#  2.25449087e+01 4.16362885e+08 7.72479714e+05 5.36349632e+00
#  8.47127870e+05 2.93503735e+05 2.69982881e+15 2.70617609e+15
#  3.19231714e+15 3.81772898e+15 3.55499109e+15 3.16314155e+15
#  1.50935941e+15 3.08160095e+14 2.54088898e+13 1.55530899e+09
#  3.73215513e+13 5.57564255e+08 1.74048944e+01 4.61328819e+16
#  2.25319326e+01]
# train_scaled.shape = (1175, 81)
# train_scaled.shape = (1175, 83)
#      Deaths  Confirmed_lag_1  Deaths_lag_1  \
# 0 -0.385293              NaN           NaN
# 1 -0.385293        -0.451783     -0.389299
# 2 -0.385293        -0.451195     -0.389299
# 3 -0.384308        -0.450656     -0.389299
# 4 -0.384308        -0.449775     -0.388269
#
#    Case fatality rate of COVID-19 (%)_lag_1  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    Daily new confirmed cases of COVID-19 (rolling 3-day average)_lag_1  \
# 0                                                NaN
# 1                                          -0.356664
# 2                                          -0.355780
# 3                                          -0.353720
# 4                                          -0.347243
#
#    Daily new confirmed deaths due to COVID-19 (rolling 3-day average)_lag_1  \
# 0                                                NaN
# 1                                          -0.234494
# 2                                          -0.234494
# 3                                          -0.234494
# 4                                          -0.233866
#
#    Age 0-9_lag_1  Age 10-19_lag_1  Age 20-29_lag_1  Age 30-39_lag_1  ...  \
# 0            NaN              NaN              NaN              NaN  ...
# 1      -0.297826        -0.300435        -0.314661        -0.329422  ...
# 2      -0.297826        -0.300435        -0.314661        -0.329422  ...
# 3      -0.297826        -0.300435        -0.314661        -0.329422  ...
# 4      -0.297826        -0.300435        -0.314661        -0.329422  ...
#
#    Age 70-79_lag_4  Age >80_lag_4  # People_lag_4  GDP_lag_4  \
# 0              NaN            NaN             NaN        NaN
# 1              NaN            NaN             NaN        NaN
# 2              NaN            NaN             NaN        NaN
# 3              NaN            NaN             NaN        NaN
# 4        -0.389278      -0.439566       -0.346331  -0.410222
#
#    GDP per capta_lag_4  Life expectancy_lag_4  # Flight Passengers_lag_4  \
# 0                  NaN                    NaN                        NaN
# 1                  NaN                    NaN                        NaN
# 2                  NaN                    NaN                        NaN
# 3                  NaN                    NaN                        NaN
# 4            -1.001727              -0.758097                  -0.527613
#
#    Hospital beds (per 1,000 people)_lag_4       Date  country_code
# 0                                     NaN 2020-03-16             0
# 1                                     NaN 2020-03-17             0
# 2                                     NaN 2020-03-18             0
# 3                                     NaN 2020-03-19             0
# 4                                -0.32427 2020-03-20             0
#
# [5 rows x 83 columns]

# %%
valid_scaled = valid[['Date', 'country_code']]
for col in tqdm_notebook(cols_list):
    feat_list = [col + '_lag_' + str(shift) for shift in range(1, N+1)]
    temp = valid.apply(lambda row: scale_row(row[feat_list], row[col+'_mean'], row[col+'_std']), axis=1)
    valid_scaled = pd.concat([valid_scaled, temp], axis=1)
    
# Now the entire valid set is scaled
valid_scaled.head()
# Out:
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
#          Date  country_code  Confirmed_lag_1  Confirmed_lag_2  \
# 12 2020-03-28             0         1.250497         0.364198
# 13 2020-03-29             0         1.149419         0.365018
# 14 2020-03-30             0         1.052597         0.542528
# 15 2020-03-31             0         1.121034         0.349680
# 16 2020-04-01             0         1.414696        -0.045233
#
#     Confirmed_lag_3  Confirmed_lag_4  Deaths_lag_1  Deaths_lag_2  \
# 12        -0.807347        -0.807347      1.358732      0.000000
# 13        -0.310654        -1.203783      1.319824      0.219971
# 14        -0.394144        -1.200980      0.914807      0.699559
# 15        -0.215979        -1.254735      1.154878      0.182349
# 16        -0.513159        -0.856304      1.276444      0.303915
#
#     Deaths_lag_3  Deaths_lag_4  ...  Life expectancy_lag_3  \
# 12     -0.339683     -1.019049  ...                    0.0
# 13     -0.659912     -0.879883  ...                    0.0
# 14     -0.376685     -1.237681  ...                    0.0
# 15     -0.060783     -1.276444  ...                    0.0
# 16     -0.668614     -0.911746  ...                    0.0
#
#     Life expectancy_lag_4  # Flight Passengers_lag_1  \
# 12                    0.0                        0.0
# 13                    0.0                        0.0
# 14                    0.0                        0.0
# 15                    0.0                        0.0
# 16                    0.0                        0.0
#
#     # Flight Passengers_lag_2  # Flight Passengers_lag_3  \
# 12                        0.0                        0.0
# 13                        0.0                        0.0
# 14                        0.0                        0.0
# 15                        0.0                        0.0
# 16                        0.0                        0.0
#
#     # Flight Passengers_lag_4  Hospital beds (per 1,000 people)_lag_1  \
# 12                        0.0                                     0.0
# 13                        0.0                                     0.0
# 14                        0.0                                     0.0
# 15                        0.0                                     0.0
# 16                        0.0                                     0.0
#
#     Hospital beds (per 1,000 people)_lag_2  \
# 12                                     0.0
# 13                                     0.0
# 14                                     0.0
# 15                                     0.0
# 16                                     0.0
#
#     Hospital beds (per 1,000 people)_lag_3  \
# 12                                     0.0
# 13                                     0.0
# 14                                     0.0
# 15                                     0.0
# 16                                     0.0
#
#     Hospital beds (per 1,000 people)_lag_4
# 12                                     0.0
# 13                                     0.0
# 14                                     0.0
# 15                                     0.0
# 16                                     0.0
#
# [5 rows x 82 columns]

# %%
valid_br_scaled = valid_br[['Date', 'country_code']]
for col in tqdm_notebook(cols_list):
    feat_list = [col + '_lag_' + str(shift) for shift in range(1, N+1)]
    temp = valid_br.apply(lambda row: scale_row(row[feat_list], row[col+'_mean'], row[col+'_std']), axis=1)
    valid_br_scaled = pd.concat([valid_br_scaled, temp], axis=1)
    
# Now the entire valid_br set is scaled
valid_br_scaled.head()
# Out:
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
#           Date  country_code  Confirmed_lag_1  Confirmed_lag_2  \
# 116 2020-03-28             4         1.207609         0.361058
# 117 2020-03-29             4         1.190206         0.348943
# 118 2020-03-30             4         1.106718         0.473794
# 119 2020-03-31             4         1.084493         0.435806
# 120 2020-04-01             4         1.404555        -0.044569
#
#      Confirmed_lag_3  Confirmed_lag_4  Deaths_lag_1  Deaths_lag_2  \
# 116        -0.483533        -1.085133      1.164852      0.421329
# 117        -0.397311        -1.141838      1.187977      0.328108
# 118        -0.401871        -1.178641      1.256433      0.274845
# 119        -0.271123        -1.249176      1.180796      0.393599
# 120        -0.455876        -0.904111      1.287939      0.189595
#
#      Deaths_lag_3  Deaths_lag_4  ...  Life expectancy_lag_3  \
# 116     -0.470898     -1.115284  ...           2.676777e-08
# 117     -0.350736     -1.165349  ...           2.676777e-08
# 118     -0.471162     -1.060115  ...           2.676777e-08
# 119     -0.462051     -1.112344  ...           2.676777e-08
# 120     -0.411879     -1.065655  ...           2.676777e-08
#
#      Life expectancy_lag_4  # Flight Passengers_lag_1  \
# 116           2.676777e-08                        0.0
# 117           2.676777e-08                        0.0
# 118           2.676777e-08                        0.0
# 119           2.676777e-08                        0.0
# 120           2.676777e-08                        0.0
#
#      # Flight Passengers_lag_2  # Flight Passengers_lag_3  \
# 116                        0.0                        0.0
# 117                        0.0                        0.0
# 118                        0.0                        0.0
# 119                        0.0                        0.0
# 120                        0.0                        0.0
#
#      # Flight Passengers_lag_4  Hospital beds (per 1,000 people)_lag_1  \
# 116                        0.0                                     0.0
# 117                        0.0                                     0.0
# 118                        0.0                                     0.0
# 119                        0.0                                     0.0
# 120                        0.0                                     0.0
#
#      Hospital beds (per 1,000 people)_lag_2  \
# 116                                     0.0
# 117                                     0.0
# 118                                     0.0
# 119                                     0.0
# 120                                     0.0
#
#      Hospital beds (per 1,000 people)_lag_3  \
# 116                                     0.0
# 117                                     0.0
# 118                                     0.0
# 119                                     0.0
# 120                                     0.0
#
#      Hospital beds (per 1,000 people)_lag_4
# 116                                     0.0
# 117                                     0.0
# 118                                     0.0
# 119                                     0.0
# 120                                     0.0
#
# [5 rows x 82 columns]

# %%
valid_sp_scaled = valid_sp[['Date', 'country_code']]
for col in tqdm_notebook(cols_list):
    feat_list = [col + '_lag_' + str(shift) for shift in range(1, N+1)]
    temp = valid_sp.apply(lambda row: scale_row(row[feat_list], row[col+'_mean'], row[col+'_std']), axis=1)
    valid_sp_scaled = pd.concat([valid_sp_scaled, temp], axis=1)
    
# Now the entire valid_sp set is scaled
valid_sp_scaled.head()
# Out:
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
#            Date  country_code  Confirmed_lag_1  Confirmed_lag_2  \
# 1261 2020-03-28            48         0.942716         0.488961
# 1262 2020-03-29            48         0.763291         0.763291
# 1263 2020-03-30            48         0.500000         0.500000
# 1264 2020-03-31            48         1.500000        -0.500000
#
#       Confirmed_lag_3  Confirmed_lag_4  Deaths_lag_1  Deaths_lag_2  \
# 1261        -0.064934        -1.366743      1.179235      0.378245
# 1262        -0.184693        -1.341888      0.783349      0.783349
# 1263         0.500000        -1.500000      0.500000      0.500000
# 1264        -0.500000        -0.500000      1.500000     -0.500000
#
#       Deaths_lag_3  Deaths_lag_4  ...  Life expectancy_lag_3  \
# 1261     -0.422744     -1.134735  ...                    NaN
# 1262     -0.261116     -1.305582  ...                    NaN
# 1263      0.500000     -1.500000  ...                    NaN
# 1264     -0.500000     -0.500000  ...                    NaN
#
#       Life expectancy_lag_4  # Flight Passengers_lag_1  \
# 1261                    NaN                        NaN
# 1262                    NaN                        NaN
# 1263                    NaN                        NaN
# 1264                    NaN                        NaN
#
#       # Flight Passengers_lag_2  # Flight Passengers_lag_3  \
# 1261                        NaN                        NaN
# 1262                        NaN                        NaN
# 1263                        NaN                        NaN
# 1264                        NaN                        NaN
#
#       # Flight Passengers_lag_4  Hospital beds (per 1,000 people)_lag_1  \
# 1261                        NaN                                     NaN
# 1262                        NaN                                     NaN
# 1263                        NaN                                     NaN
# 1264                        NaN                                     NaN
#
#       Hospital beds (per 1,000 people)_lag_2  \
# 1261                                     NaN
# 1262                                     NaN
# 1263                                     NaN
# 1264                                     NaN
#
#       Hospital beds (per 1,000 people)_lag_3  \
# 1261                                     NaN
# 1262                                     NaN
# 1263                                     NaN
# 1264                                     NaN
#
#       Hospital beds (per 1,000 people)_lag_4
# 1261                                     NaN
# 1262                                     NaN
# 1263                                     NaN
# 1264                                     NaN
#
# [4 rows x 82 columns]

# %%
valid_nyc_scaled = valid_nyc[['Date', 'country_code']]
for col in tqdm_notebook(cols_list):
    feat_list = [col + '_lag_' + str(shift) for shift in range(1, N+1)]
    temp = valid_nyc.apply(lambda row: scale_row(row[feat_list], row[col+'_mean'], row[col+'_std']), axis=1)
    valid_nyc_scaled = pd.concat([valid_nyc_scaled, temp], axis=1)
    
# Now the entire valid_nyc set is scaled
valid_nyc_scaled.head()
# Out:
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
#           Date  country_code  Confirmed_lag_1  Confirmed_lag_2  \
# 825 2020-03-28            30         1.185099         0.390955
# 826 2020-03-29            30         1.178751         0.353930
# 827 2020-03-30            30         1.168795         0.393804
#
#      Confirmed_lag_3  Confirmed_lag_4  Deaths_lag_1  Deaths_lag_2  \
# 825        -0.471228        -1.104826      1.196800      0.361252
# 826        -0.372180        -1.160500      1.297398      0.185868
# 827        -0.422148        -1.140451      1.244389      0.323255
#
#      Deaths_lag_3  Deaths_lag_4  ...  Life expectancy_lag_3  \
# 825     -0.444807     -1.113245  ...                    NaN
# 826     -0.439827     -1.043439  ...                    NaN
# 827     -0.540665     -1.026978  ...                    NaN
#
#      Life expectancy_lag_4  # Flight Passengers_lag_1  \
# 825                    NaN                        NaN
# 826                    NaN                        NaN
# 827                    NaN                        NaN
#
#      # Flight Passengers_lag_2  # Flight Passengers_lag_3  \
# 825                        NaN                        NaN
# 826                        NaN                        NaN
# 827                        NaN                        NaN
#
#      # Flight Passengers_lag_4  Hospital beds (per 1,000 people)_lag_1  \
# 825                        NaN                                     NaN
# 826                        NaN                                     NaN
# 827                        NaN                                     NaN
#
#      Hospital beds (per 1,000 people)_lag_2  \
# 825                                     NaN
# 826                                     NaN
# 827                                     NaN
#
#      Hospital beds (per 1,000 people)_lag_3  \
# 825                                     NaN
# 826                                     NaN
# 827                                     NaN
#
#      Hospital beds (per 1,000 people)_lag_4
# 825                                     NaN
# 826                                     NaN
# 827                                     NaN
#
# [3 rows x 82 columns]

# %%
valid_sk_scaled = valid_sk[['Date', 'country_code']]
for col in tqdm_notebook(cols_list):
    feat_list = [col + '_lag_' + str(shift) for shift in range(1, N+1)]
    temp = valid_sk.apply(lambda row: scale_row(row[feat_list], row[col+'_mean'], row[col+'_std']), axis=1)
    valid_sk_scaled = pd.concat([valid_sk_scaled, temp], axis=1)
    
# Now the entire valid_sk set is scaled
valid_sk_scaled.head()
# Out:
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
#            Date  country_code  Confirmed_lag_1  Confirmed_lag_2  \
# 1152 2020-03-28            44         1.137212         0.424742
# 1153 2020-03-29            44         1.251784         0.242058
# 1154 2020-03-30            44         1.149046         0.457643
# 1155 2020-03-31            44         1.036192         0.488240
# 1156 2020-04-01            44         1.224600         0.261864
#
#       Confirmed_lag_3  Confirmed_lag_4  Deaths_lag_1  Deaths_lag_2  \
# 1152        -0.389510        -1.172444      1.243540      0.248708
# 1153        -0.387292        -1.106549      1.119186      0.497416
# 1154        -0.503737        -1.102953      1.191439      0.283676
# 1155        -0.249389        -1.275043      1.157792      0.445305
# 1156        -0.338883        -1.147581      1.021508      0.510754
#
#       Deaths_lag_3  Deaths_lag_4  ...  Life expectancy_lag_3  \
# 1152     -0.373062     -1.119186  ...                    0.0
# 1153     -0.497416     -1.119186  ...                    0.0
# 1154     -0.283676     -1.191439  ...                    0.0
# 1155     -0.504678     -1.098418  ...                    0.0
# 1156     -0.255377     -1.276885  ...                    0.0
#
#       Life expectancy_lag_4  # Flight Passengers_lag_1  \
# 1152                    0.0                   -0.00006
# 1153                    0.0                   -0.00006
# 1154                    0.0                   -0.00006
# 1155                    0.0                   -0.00006
# 1156                    0.0                   -0.00006
#
#       # Flight Passengers_lag_2  # Flight Passengers_lag_3  \
# 1152                   -0.00006                   -0.00006
# 1153                   -0.00006                   -0.00006
# 1154                   -0.00006                   -0.00006
# 1155                   -0.00006                   -0.00006
# 1156                   -0.00006                   -0.00006
#
#       # Flight Passengers_lag_4  Hospital beds (per 1,000 people)_lag_1  \
# 1152                   -0.00006                           -4.470348e-08
# 1153                   -0.00006                           -4.470348e-08
# 1154                   -0.00006                           -4.470348e-08
# 1155                   -0.00006                           -4.470348e-08
# 1156                   -0.00006                           -4.470348e-08
#
#       Hospital beds (per 1,000 people)_lag_2  \
# 1152                           -4.470348e-08
# 1153                           -4.470348e-08
# 1154                           -4.470348e-08
# 1155                           -4.470348e-08
# 1156                           -4.470348e-08
#
#       Hospital beds (per 1,000 people)_lag_3  \
# 1152                           -4.470348e-08
# 1153                           -4.470348e-08
# 1154                           -4.470348e-08
# 1155                           -4.470348e-08
# 1156                           -4.470348e-08
#
#       Hospital beds (per 1,000 people)_lag_4
# 1152                           -4.470348e-08
# 1153                           -4.470348e-08
# 1154                           -4.470348e-08
# 1155                           -4.470348e-08
# 1156                           -4.470348e-08
#
# [5 rows x 82 columns]

# %%
valid_lombardia_scaled = valid_lombardia[['Date', 'country_code']]
for col in tqdm_notebook(cols_list):
    feat_list = [col + '_lag_' + str(shift) for shift in range(1, N+1)]
    temp = valid_lombardia.apply(lambda row: scale_row(row[feat_list], row[col+'_mean'], row[col+'_std']), axis=1)
    valid_lombardia_scaled = pd.concat([valid_lombardia_scaled, temp], axis=1)
    
# Now the entire valid_lombardia set is scaled
valid_lombardia_scaled.head()
# Out:
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
#           Date  country_code  Confirmed_lag_1  Confirmed_lag_2  \
# 712 2020-03-28            25         1.205564         0.373175
# 713 2020-03-29            25         1.123434         0.429645
# 714 2020-03-30            25         1.075856         0.475887
# 715 2020-03-31            25         1.039549         0.491956
# 716 2020-04-01            25         1.082434         0.438600
#
#      Confirmed_lag_3  Confirmed_lag_4  Deaths_lag_1  Deaths_lag_2  \
# 712        -0.505514        -1.073225      1.273097      0.250081
# 713        -0.359840        -1.193239      1.207023      0.361522
# 714        -0.321937        -1.229806      1.102053      0.463760
# 715        -0.263476        -1.268029      1.139307      0.379769
# 716        -0.271031        -1.250003      1.134287      0.435841
#
#      Deaths_lag_3  Deaths_lag_4  ...  Life expectancy_lag_3  \
# 712     -0.481725     -1.041453  ...                    NaN
# 713     -0.482419     -1.086126  ...                    NaN
# 714     -0.367862     -1.197950  ...                    NaN
# 715     -0.310117     -1.208959  ...                    NaN
# 716     -0.403760     -1.166368  ...                    NaN
#
#      Life expectancy_lag_4  # Flight Passengers_lag_1  \
# 712                    NaN                        NaN
# 713                    NaN                        NaN
# 714                    NaN                        NaN
# 715                    NaN                        NaN
# 716                    NaN                        NaN
#
#      # Flight Passengers_lag_2  # Flight Passengers_lag_3  \
# 712                        NaN                        NaN
# 713                        NaN                        NaN
# 714                        NaN                        NaN
# 715                        NaN                        NaN
# 716                        NaN                        NaN
#
#      # Flight Passengers_lag_4  Hospital beds (per 1,000 people)_lag_1  \
# 712                        NaN                                     NaN
# 713                        NaN                                     NaN
# 714                        NaN                                     NaN
# 715                        NaN                                     NaN
# 716                        NaN                                     NaN
#
#      Hospital beds (per 1,000 people)_lag_2  \
# 712                                     NaN
# 713                                     NaN
# 714                                     NaN
# 715                                     NaN
# 716                                     NaN
#
#      Hospital beds (per 1,000 people)_lag_3  \
# 712                                     NaN
# 713                                     NaN
# 714                                     NaN
# 715                                     NaN
# 716                                     NaN
#
#      Hospital beds (per 1,000 people)_lag_4
# 712                                     NaN
# 713                                     NaN
# 714                                     NaN
# 715                                     NaN
# 716                                     NaN
#
# [5 rows x 82 columns]

# %%
valid_wuhua_scaled = valid_wuhua[['Date', 'country_code']]
for col in tqdm_notebook(cols_list):
    feat_list = [col + '_lag_' + str(shift) for shift in range(1, N+1)]
    temp = valid_wuhua.apply(lambda row: scale_row(row[feat_list], row[col+'_mean'], row[col+'_std']), axis=1)
    valid_wuhua_scaled = pd.concat([valid_wuhua_scaled, temp], axis=1)
    
# Now the entire valid_wuhua set is scaled
valid_wuhua_scaled.head()
# Out:
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
#            Date  country_code  Confirmed_lag_1  Confirmed_lag_2  \
# 1437 2020-03-28            53              0.0              0.0
# 1438 2020-03-29            53              0.0              0.0
# 1439 2020-03-30            53              0.0              0.0
# 1440 2020-03-31            53              0.0              0.0
# 1441 2020-04-01            53              0.0              0.0
#
#       Confirmed_lag_3  Confirmed_lag_4  Deaths_lag_1  Deaths_lag_2  \
# 1437              0.0              0.0      1.200961      0.400320
# 1438              0.0              0.0      1.019489      0.530134
# 1439              0.0              0.0      1.193381      0.275396
# 1440              0.0              0.0      1.175901      0.423324
# 1441              0.0              0.0      0.879883      0.659912
#
#       Deaths_lag_3  Deaths_lag_4  ...  Life expectancy_lag_3  \
# 1437     -0.560449     -1.040833  ...                    NaN
# 1438     -0.285457     -1.264166  ...                    NaN
# 1439     -0.275396     -1.193381  ...                    NaN
# 1440     -0.517396     -1.081829  ...                    NaN
# 1441     -0.219971     -1.319824  ...                    NaN
#
#       Life expectancy_lag_4  # Flight Passengers_lag_1  \
# 1437                    NaN                        NaN
# 1438                    NaN                        NaN
# 1439                    NaN                        NaN
# 1440                    NaN                        NaN
# 1441                    NaN                        NaN
#
#       # Flight Passengers_lag_2  # Flight Passengers_lag_3  \
# 1437                        NaN                        NaN
# 1438                        NaN                        NaN
# 1439                        NaN                        NaN
# 1440                        NaN                        NaN
# 1441                        NaN                        NaN
#
#       # Flight Passengers_lag_4  Hospital beds (per 1,000 people)_lag_1  \
# 1437                        NaN                                     NaN
# 1438                        NaN                                     NaN
# 1439                        NaN                                     NaN
# 1440                        NaN                                     NaN
# 1441                        NaN                                     NaN
#
#       Hospital beds (per 1,000 people)_lag_2  \
# 1437                                     NaN
# 1438                                     NaN
# 1439                                     NaN
# 1440                                     NaN
# 1441                                     NaN
#
#       Hospital beds (per 1,000 people)_lag_3  \
# 1437                                     NaN
# 1438                                     NaN
# 1439                                     NaN
# 1440                                     NaN
# 1441                                     NaN
#
#       Hospital beds (per 1,000 people)_lag_4
# 1437                                     NaN
# 1438                                     NaN
# 1439                                     NaN
# 1440                                     NaN
# 1441                                     NaN
#
# [5 rows x 82 columns]

# %% [markdown]
# # Split into X and y

# %%
features = ['country_code']
for i in range(1,N+1):
    for col in lag_cols:
        features.append(col + "_lag_" + str(i))
    
target = "Deaths"


# Split into X and y
X_train = train[features]
y_train = train[target]
X_valid = valid[features]
y_valid = valid[target]
X_valid_br = valid_br[features]
y_valid_br = valid_br[target]
X_valid_sk = valid_sk[features]
y_valid_sk = valid_sk[target]
X_valid_sp = valid_sp[features]
y_valid_sp = valid_sp[target]
X_valid_nyc = valid_nyc[features]
y_valid_nyc = valid_nyc[target]
X_valid_lombardia = valid_lombardia[features]
y_valid_lombardia = valid_lombardia[target]
X_valid_wuhua = valid_wuhua[features]
y_valid_wuhua = valid_wuhua[target]

print("X_train.shape = " + str(X_train.shape))
print("y_train.shape = " + str(y_train.shape))
print("X_valid.shape = " + str(X_valid.shape))
print("y_valid_br.shape = " + str(y_valid_br.shape))
print("X_valid_br.shape = " + str(X_valid_br.shape))
print("y_valid.shape = " + str(y_valid.shape))
# Out:
# X_train.shape = (1175, 81)
# y_train.shape = (1175,)
# X_valid.shape = (268, 81)
# y_valid_br.shape = (5,)
# X_valid_br.shape = (5, 81)
# y_valid.shape = (268,)

# %%
# Split into X and y
X_train_scaled = train_scaled[features]
y_train_scaled = train_scaled[target]
X_valid_scaled = valid_scaled[features]
X_valid_br_scaled = valid_br_scaled[features]
X_valid_sk_scaled = valid_sk_scaled[features]
X_valid_sp_scaled = valid_sp_scaled[features]
X_valid_nyc_scaled = valid_nyc_scaled[features]
X_valid_lombardia_scaled = valid_lombardia_scaled[features]
X_valid_wuhua_scaled = valid_wuhua_scaled[features]


print("X_train_scaled.shape = " + str(X_train_scaled.shape))
print("y_train_scaled.shape = " + str(y_train_scaled.shape))
print("X_valid_scaled.shape = " + str(X_valid_scaled.shape))
print("X_valid_br_scaled.shape = " + str(X_valid_br_scaled.shape))
print("X_valid_sk_scaled.shape = " + str(X_valid_sk_scaled.shape))
print("X_valid_sp_scaled.shape = " + str(X_valid_sp_scaled.shape))
print("X_valid_nyc_scaled.shape = " + str(X_valid_nyc_scaled.shape))
print("X_valid_lombardia_scaled.shape = " + str(X_valid_lombardia_scaled.shape))
print("X_valid_wuhua_scaled.shape = " + str(X_valid_wuhua_scaled.shape))
# Out:
# X_train_scaled.shape = (1175, 81)
# y_train_scaled.shape = (1175,)
# X_valid_scaled.shape = (268, 81)
# X_valid_br_scaled.shape = (5, 81)
# X_valid_sk_scaled.shape = (5, 81)
# X_valid_sp_scaled.shape = (4, 81)
# X_valid_nyc_scaled.shape = (3, 81)
# X_valid_lombardia_scaled.shape = (5, 81)
# X_valid_wuhua_scaled.shape = (6, 81)

# %% [markdown]
# # Train the model using XGBoost

# %%
# Create the model
model = XGBRegressor(seed=model_seed,
                     n_estimators=n_estimators,
                     max_depth=max_depth,
                     learning_rate=learning_rate,
                     min_child_weight=min_child_weight,
                     subsample=subsample,
                     colsample_bytree=colsample_bytree,
                     colsample_bylevel=colsample_bylevel,
                     gamma=gamma)

# Train the regressor
model.fit(X_train_scaled, y_train_scaled)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints=None,
#              learning_rate=0.1, max_delta_step=0, max_depth=3,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=100, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, seed=100, subsample=1,
#              tree_method=None, validate_parameters=False, verbosity=None)

# %% [markdown]
# # Predict on train set

# %%
# Do prediction on train set
est_scaled = model.predict(X_train_scaled)
est = est_scaled * math.sqrt(scaler.var_[0]) + scaler.mean_[0]

# Calculate RMSE
print("RMSE on train set = %0.3f" % math.sqrt(mean_squared_error(y_train, est)))

# Calculate MAPE
print("MAPE on train set = %0.3f%%" % get_mape(y_train, est))

est_df = pd.DataFrame({'est': est, 
                       'Date': train['Date'], 
                       'Country': train['Country']})

country = 'Brazil'
mask_train = (train['Country'] == country)
mask_valid = (valid['Country'] == country)
mask_est = (est_df['Country'] == country)

ax = train.loc[mask_train].plot(x='Date', y='Deaths', style='b-', grid=True)
ax = valid.loc[mask_valid].plot(x='Date', y='Deaths', style='y-', grid=True, ax=ax)
ax = est_df.loc[mask_est].plot(x='Date', y='est', style='r-', grid=True, ax=ax)
ax.legend(['train', 'validation', 'predictions'])
ax.set_xlabel("Date")
ax.set_ylabel("Deaths")
# Out:
# RMSE on train set = 15.038
# MAPE on train set = inf%
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in true_divide
# Text(0, 0.5, 'Deaths')

# %% [markdown]
# # Predict on valid set brasil

# %%
# Do prediction on test set
est_scaled_br = model.predict(X_valid_br_scaled)
valid_br['est_scaled_br'] = est_scaled_br
valid_br['est'] = valid_br['est_scaled_br'] * valid_br['Deaths_std'] + valid_br['Deaths_mean']

# Calculate RMSE
rmse_bef_tuning = math.sqrt(mean_squared_error(y_valid_br, valid_br['est']))
print("RMSE on dev set = %0.3f" % rmse_bef_tuning)

# Calculate MAPE
mape_bef_tuning = get_mape(y_valid_br, valid_br['est'])
print("MAPE on dev set = %0.3f%%" % mape_bef_tuning)

est_df = pd.DataFrame({'est': valid_br['est'], 
                       'y_valid_br': y_valid_br,
                       'Date': valid_br['Date']})

ax = valid_br.plot(x='Date', y='Deaths', style='y-', grid=True)
ax = est_df.plot(x='Date', y='est', style='r-', grid=True, ax=ax)
ax.legend(['validation', 'predictions'])
ax.set_xlabel("Date")
ax.set_ylabel("Deaths")
ax.set_title("Brazil")
# Out:
# RMSE on dev set = 31.402
# MAPE on dev set = 17.644%
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# Text(0.5, 1.0, 'Brazil')

# %% [markdown]
# # Predict on valid set Koreia do Sul

# %%
# Do prediction on test set
est_scaled_sk = model.predict(X_valid_sk_scaled)
valid_sk['est_scaled_sk'] = est_scaled_sk
valid_sk['est'] = valid_sk['est_scaled_sk'] * valid_sk['Deaths_std'] + valid_sk['Deaths_mean']

# Calculate RMSE
rmse_bef_tuning = math.sqrt(mean_squared_error(y_valid_sk, valid_sk['est']))
print("RMSE on dev set = %0.3f" % rmse_bef_tuning)

# Calculate MAPE
mape_bef_tuning = get_mape(y_valid_sk, valid_sk['est'])
print("MAPE on dev set = %0.3f%%" % mape_bef_tuning)

est_df = pd.DataFrame({'est': valid_sk['est'], 
                       'y_valid_sk': y_valid_sk,
                       'Date': valid_sk['Date']})

ax = valid_sk.plot(x='Date', y='Deaths', style='y-', grid=True)
ax = est_df.plot(x='Date', y='est', style='r-', grid=True, ax=ax)
ax.legend(['validation', 'predictions'])
ax.set_xlabel("Date")
ax.set_ylabel("Deaths")
ax.set_title("South Korea")
# Out:
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# RMSE on dev set = 5.288
# MAPE on dev set = 3.197%
# Text(0.5, 1.0, 'South Korea')

# %% [markdown]
# # Predict New York

# %%
# Do prediction on test set
est_scaled_nyc = model.predict(X_valid_nyc_scaled)
valid_nyc['est_scaled_nyc'] = est_scaled_nyc
valid_nyc['est'] = valid_nyc['est_scaled_nyc'] * valid_nyc['Deaths_std'] + valid_nyc['Deaths_mean']

# Calculate RMSE
rmse_bef_tuning = math.sqrt(mean_squared_error(y_valid_nyc, valid_nyc['est']))
print("RMSE on dev set = %0.3f" % rmse_bef_tuning)

# Calculate MAPE
mape_bef_tuning = get_mape(y_valid_nyc, valid_nyc['est'])
print("MAPE on dev set = %0.3f%%" % mape_bef_tuning)

est_df = pd.DataFrame({'est': valid_nyc['est'], 
                       'y_valid_nyc': y_valid_nyc,
                       'Date': valid_nyc['Date']})

ax = valid_nyc.plot(x='Date', y='Deaths', style='y-', grid=True)
ax = est_df.plot(x='Date', y='est', style='r-', grid=True, ax=ax)
ax.legend(['validation', 'predictions'])
ax.set_xlabel("Date")
ax.set_ylabel("Deaths")
ax.set_title("New York")
# Out:
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# RMSE on dev set = 145.183
# MAPE on dev set = 22.670%
# Text(0.5, 1.0, 'New York')

# %% [markdown]
# # Predict on valid set Lombardia

# %%
# Do prediction on test set
est_scaled_lombardia = model.predict(X_valid_lombardia_scaled)
valid_lombardia['est_scaled_lombardia'] = est_scaled_lombardia
valid_lombardia['est'] = valid_lombardia['est_scaled_lombardia'] * valid_lombardia['Deaths_std'] + valid_lombardia['Deaths_mean']

# Calculate RMSE
rmse_bef_tuning = math.sqrt(mean_squared_error(y_valid_lombardia, valid_lombardia['est']))
print("RMSE on dev set = %0.3f" % rmse_bef_tuning)

# Calculate MAPE
mape_bef_tuning = get_mape(y_valid_lombardia, valid_lombardia['est'])
print("MAPE on dev set = %0.3f%%" % mape_bef_tuning)

est_df = pd.DataFrame({'est': valid_lombardia['est'], 
                       'y_valid_lombardia': y_valid_lombardia,
                       'Date': valid_lombardia['Date']})

ax = valid_lombardia.plot(x='Date', y='Deaths', style='y-', grid=True)
ax = est_df.plot(x='Date', y='est', style='r-', grid=True, ax=ax)
ax.legend(['validation', 'predictions'])
ax.set_xlabel("Date")
ax.set_ylabel("Deaths")
ax.set_title("Lombardia")
# Out:
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# RMSE on dev set = 433.086
# MAPE on dev set = 6.379%
# Text(0.5, 1.0, 'Lombardia')

# %% [markdown]
# # Predict Wuhan

# %%
# Do prediction on test set
est_scaled_wuhua = model.predict(X_valid_wuhua_scaled)
valid_wuhua['est_scaled_wuhua'] = est_scaled_wuhua
valid_wuhua['est'] = valid_wuhua['est_scaled_wuhua'] * valid_wuhua['Deaths_std'] + valid_wuhua['Deaths_mean']

# Calculate RMSE
rmse_bef_tuning = math.sqrt(mean_squared_error(y_valid_wuhua, valid_wuhua['est']))
print("RMSE on dev set = %0.3f" % rmse_bef_tuning)

# Calculate MAPE
mape_bef_tuning = get_mape(y_valid_wuhua, valid_wuhua['est'])
print("MAPE on dev set = %0.3f%%" % mape_bef_tuning)

est_df = pd.DataFrame({'est': valid_wuhua['est'], 
                       'y_valid_wuhua': y_valid_wuhua,
                       'Date': valid_wuhua['Date']})

ax = valid_wuhua.plot(x='Date', y='Deaths', style='y-', grid=True)
ax = est_df.plot(x='Date', y='est', style='r-', grid=True, ax=ax)
ax.legend(['validation', 'predictions'])
ax.set_xlabel("Date")
ax.set_ylabel("Deaths")
ax.set_title("Wuhan")
# Out:
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/anaconda3/envs/ml-env/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# RMSE on dev set = 4.373
# MAPE on dev set = 0.126%
# Text(0.5, 1.0, 'Wuhan')
